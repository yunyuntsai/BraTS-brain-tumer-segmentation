# %%
import os
import numpy as np
import tensorflow as tf
import sklearn
import pylab  
import datetime
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import cv2
import nibabel as nib
import math
import random
import time
from scipy import ndimage
from sklearn.metrics import f1_score
from scipy.spatial.distance import directed_hausdorff
import numpy as np
import csv
# %matplotlib inline

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
def npmin(dd):
    return np.min(dd)
def npmax(dd):
    return np.max(dd)
def npmean(dd):
    return np.mean(dd)
def norm (data):
    return (data - npmin(data)) / (npmax(data) - npmin(data))*1

# %%
isTrain = True
checkpoint_dir = "checkpoint_flair"
epoch = 50
batch_size = 1
output_class_num = 4

# %%
def scale_3d(src, md='nearest'):
    depth=128
    height=128
    width=128
    out = ndimage.zoom(src,(depth/src.shape[0],height/src.shape[1],width/src.shape[2]),mode = md,order = 0)
    return out

# %%
def value2onehot(label):
#     label = label[...,np.newaxis]
#     label = np.repeat(label, output_class_num+1, axis=3)
    l0=[]
    for i in range(label.shape[0]):
        l1=[]
        for j in range(label.shape[1]):
            l2=[]
            for k in range(label.shape[2]):
                if label[i,j,k]==0:
                    l2.append([1,0,0,0])
                elif label[i,j,k]==0.25:
                    l2.append([0,1,0,0])
                elif label[i,j,k]==0.5:
                    l2.append([0,0,1,0])
                elif label[i,j,k]==1:
                    l2.append([0,0,0,1])
            l1.append(l2)
        l0.append(l1)
    l0 = np.asarray(l0, dtype=np.uint8)
    #print(l0.shape)
    return l0

def onehot2value(label_batch):
    l0_batch=[]
    #for l in range(label_batch.shape[0]):
    label = label_batch
    l0=[]
    for i in range(label.shape[0]):
        l1=[]
        for j in range(label.shape[1]):
            l2=[]
            for k in range(label.shape[2]):
                if np.argmax(label[i,j,k])==0:
                    l2.append(0)
                elif np.argmax(label[i,j,k])==1:
                    l2.append(0.25)
                    #print('!!',label[i,j,k])
                elif np.argmax(label[i,j,k])==2:
                    l2.append(0.5)
                    #print('!!',label[i,j,k])
                elif np.argmax(label[i,j,k])==3:
                    l2.append(1)
                    #print('!!',label[i,j,k])
            l1.append(l2)
        l0.append(l1)

    l0_batch = np.asarray(l0)
    #print(l0_batch.shape)
    return l0_batch

# %%
def f1score(gt, seg):
    if (np.sum(seg) + np.sum(gt)) == 0:
        return 1.0
    else:
        return np.sum(np.multiply(gt,seg))*2.0 / (np.sum(seg) + np.sum(gt))
def evaluation_return(y_true, y_pred):
    dim = len(y_true.shape)
    score=[]
    hausdorff=[]
    for k in range(y_true.shape[dim-1]):
        f1 = f1score(y_true[...,k], y_pred[...,k])
        score.append(f1)
        sym_hausdorff = max(directed_hausdorff(y_true[...,k],y_pred[...,k])[0], directed_hausdorff(y_pred[...,k],y_true[...,k])[0])
        hausdorff.append(sym_hausdorff)
    score = np.asarray(score)
    hausdorff = np.asarray(hausdorff)

#     flat_true = np.asarray(flat_true)
#     flat_pred = np.asarray(flat_pred)
#     sym_hausdorff = max(directed_hausdorff(flat_true[1:],flat_pred[1:])[0], directed_hausdorff(flat_pred[1:],flat_true[1:])[0])
    return np.mean(score[1:]), np.mean(hausdorff[1:])

def evaluation(y_true, y_pred):
    dim = len(y_true.shape)
    score=[]
    for k in range(y_true.shape[dim-1]):
        f1 = f1score(y_true[...,k], y_pred[...,k])
        score.append(f1)
        print ('type',k ,'f1 score is',f1)
    score = np.asarray(score)
    print('whole f1 score is',np.mean(score[1:]))

def mse(A,B):
    mse = ((A - B)**2).mean(axis=None)
    return mse

# %%
filedir = "../MICCAI_BraTS_2018_Data_Training/HGG/"
#filepath += "ct_train_1001_image.nii"

train_data = os.listdir(filedir)
train_array = []
t1ce_train_array = []
seg_array = []
for d in train_data:
    #print(d)
    nii_dir = os.path.join(filedir, d)
    nii_file = os.listdir(nii_dir)
    for n in nii_file:
        #print(n)
        if n.split(".")[0].split("_")[-1] == 't1ce' or n.split(".")[0].split("_")[-1] == 'seg' or n.split(".")[0].split("_")[-1] == 'flair':
            filepath = os.path.join(nii_dir, n)
            nii = nib.load(filepath)
            #print("load", filepath)
            img_array = nii.get_data()
            affine_array = nii.affine 
            img_head = nii.header
            #print(img_array.shape)
            img_array = img_array.transpose(0, 2, 1)
            img_array = img_array.transpose(1, 0, 2)
            nii_CT = img_array
            nii_CT = np.asarray(nii_CT)
            nii_CT = np.rot90(nii_CT,axes=(1,2))
            #print(nii_CT.shape)
            norm_nii_CT = nii_CT
            norm_nii_CT = norm(norm_nii_CT)

            #print(np.max(nii_CT),np.min(nii_CT))
            #print(np.max(norm_nii_CT),np.min(norm_nii_CT))
            if n.split(".")[0].split("_")[-1] == 't1ce':
                t1ce_train_array.append(norm_nii_CT)
            elif n.split(".")[0].split("_")[-1] == 'flair':
                train_array.append(norm_nii_CT)
            elif n.split(".")[0].split("_")[-1] == 'seg':
                seg_array.append(norm_nii_CT)
t1ce_train_array = np.array(t1ce_train_array)
print(t1ce_train_array.shape)
train_array = np.array(train_array)
print(train_array.shape)
seg_array = np.array(seg_array)
print(seg_array.shape)
np.save('t1ce_train_array', t1ce_train_array)
np.save('flair_train_array', train_array)
np.save('seg_array', seg_array)
# Out:
# /home/yunyun/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-843205b3ed45> in <module>
#      27             #print(nii_CT.shape)
#      28             norm_nii_CT = nii_CT
# ---> 29             norm_nii_CT = norm(norm_nii_CT)
#      30
#      31             #print(np.max(nii_CT),np.min(nii_CT))
#
# <ipython-input-2-813a439a6d56> in norm(data)
#       7     return np.mean(dd)
#       8 def norm (data):
# ----> 9     return (data - npmin(data)) / (npmax(data) - npmin(data))*1
#
# <ipython-input-2-813a439a6d56> in npmin(dd)
#       1 os.environ["CUDA_VISIBLE_DEVICES"] = "0"
#       2 def npmin(dd):
# ----> 3     return np.min(dd)
#       4 def npmax(dd):
#       5     return np.max(dd)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial)
#    2616     """
#    2617     return _wrapreduction(a, np.minimum, 'min', axis, None, out, keepdims=keepdims,
# -> 2618                           initial=initial)
#    2619
#    2620
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:

# %%
# back_check_label = onehot2value(onehot_nii_label)
# print(np.max(back_check_label),np.min(back_check_label))

# %%
input_height = 128 #onehot_nii_label.shape[1]
input_width = 128 #onehot_nii_label.shape[2]
input_depth = 128

# %%
flair_nii_CT = np.load('./flair_train_array.npy')
t1ce_nii_CT = np.load('./t1ce_train_array.npy')
print(flair_nii_CT.shape)
print(t1ce_nii_CT.shape)
# Out:
# (210, 155, 240, 240)
# (210, 155, 240, 240)

# %%
nii_label = np.load('./seg_array.npy')
print(nii_label.shape)
# Out:
# (210, 155, 240, 240)

# %%
#shuff= np.arange(40)
#np.random.shuffle(shuff)
shuff = [ 0, 15,  6, 36,  9, 33, 12, 13, 14 ,  5, 20, 11,  2, 32, 26, 34,  8,  1, 27, 18,  3, 22, 24, 23,
 16, 28, 25, 10,  4, 39, 29, 19, 30, 35, 38, 17, 37, 31, 21,  7]
print(shuff)
# Out:
# [0, 15, 6, 36, 9, 33, 12, 13, 14, 5, 20, 11, 2, 32, 26, 34, 8, 1, 27, 18, 3, 22, 24, 23, 16, 28, 25, 10, 4, 39, 29, 19, 30, 35, 38, 17, 37, 31, 21, 7]

# %%
small_nii_CT = flair_nii_CT[:40]
small_nii_label = nii_label[:40]
print(small_nii_CT.shape)
print(small_nii_label.shape)

small_nii_CT = small_nii_CT[shuff]
small_nii_label = small_nii_label[shuff]

n1 = []
n2 = []
for i in range(small_nii_CT.shape[0]):
    image1 = scale_3d(small_nii_CT[i])
    image2 = scale_3d(small_nii_label[i])
    n1.append(image1)
    n2.append(image2)
resize_nii_CT = np.asarray(n1[:35])
resize_nii_label = np.asarray(n2[:35])
valid_nii_CT = np.asarray(n1[35:])
valid_nii_label = np.asarray(n2[35:])
print(resize_nii_CT.shape)
print(resize_nii_label.shape)
print(valid_nii_CT.shape)
print(valid_nii_label.shape)
# Out:
# (40, 155, 240, 240)
# (40, 155, 240, 240)
# (35, 128, 128, 128)
# (35, 128, 128, 128)
# (5, 128, 128, 128)
# (5, 128, 128, 128)

# %%
# value to onehot
onehot_array = []
onehot_array2 = []
for i in range(resize_nii_label.shape[0]):
    onehot_nii_label = value2onehot(resize_nii_label[i])
    onehot_array.append(onehot_nii_label)

for i in range(valid_nii_label.shape[0]):
    onehot_nii_label = value2onehot(valid_nii_label[i])
    onehot_array2.append(onehot_nii_label)    

train_onehot_array = np.asarray(onehot_array, dtype=np.uint8)
valid_onehot_array = np.asarray(onehot_array2, dtype=np.uint8)

# %%
#check onehot to value
value_array = []
value_array2 = []
for i in range(train_onehot_array.shape[0]):
    value_nii_label = onehot2value(train_onehot_array[i])
    value_array.append(value_nii_label)
for i in range(valid_onehot_array.shape[0]):
    value_nii_label = onehot2value(valid_onehot_array[i])
    value_array2.append(value_nii_label)
value_array = np.asarray(value_array)
value_array2 = np.asarray(value_array2)
print(np.sum(value_array-resize_nii_label))
print(np.sum(value_array2-valid_nii_label))
# Out:
# 0.0
# 0.0

# %%
print(train_onehot_array.shape)
print(valid_onehot_array.shape)
# Out:
# (35, 128, 128, 128, 4)
# (5, 128, 128, 128, 4)

# %%
tt = 0
sl_num = 50
'''
ROIrx = 180
ROIry = 200
ROIbx = 300
ROIby = 110
ROIs = 15
'''
print('Flair CT nii image: \n')
fig = plt.figure(figsize=(20, 20))
fig.add_subplot(1,2,1)
plt.imshow(resize_nii_CT[tt][sl_num],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
fig.add_subplot(1,2,2)
#rect = patches.Rectangle((ROIrx,ROIry),ROIs,ROIs,linewidth=1,edgecolor='r',facecolor='none')
#plt.gca().add_patch(rect)
#rect = patches.Rectangle((ROIbx,ROIby),ROIs,ROIs,linewidth=1,edgecolor='b',facecolor='none')
#plt.gca().add_patch(rect)
plt.imshow(resize_nii_label[tt][sl_num],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
# fig.add_subplot(1,3,3)
# plt.imshow(norm(back_check_label)[tt],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
plt.show()

print(np.max(resize_nii_CT[tt][sl_num]),np.min(resize_nii_CT[tt][sl_num]))
print(np.max(resize_nii_label[tt][sl_num]),np.min(resize_nii_label[tt][sl_num]))

#print("red ROI",np.mean(nii_label[tt][50,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]),
#      np.std(nii_label[tt][50,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]))
#print("blue ROI",np.mean(nii_label[tt][50,ROIby:ROIby+ROIs,ROIbx:ROIbx+ROIs]),
#      np.std(nii_label[tt][50,ROIby:ROIby+ROIs,ROIbx:ROIbx+ROIs]))
# Out:
# Flair CT nii image:
# 0.6802096985583224 0.0
# 1.0 0.0

# %%
tt = 1
sl_num = 50

print('t1ne CT nii image: \n')
fig = plt.figure(figsize=(20, 20))
fig.add_subplot(1,2,1)
plt.imshow(resize_nii_CT[tt][sl_num],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
fig.add_subplot(1,2,2)
#rect = patches.Rectangle((ROIrx,ROIry),ROIs,ROIs,linewidth=1,edgecolor='r',facecolor='none')
#plt.gca().add_patch(rect)
#rect = patches.Rectangle((ROIbx,ROIby),ROIs,ROIs,linewidth=1,edgecolor='b',facecolor='none')
#plt.gca().add_patch(rect)
plt.imshow(resize_nii_label[tt][sl_num],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
# fig.add_subplot(1,3,3)
# plt.imshow(norm(back_check_label)[tt],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
plt.show()

print(np.max(resize_nii_CT[tt][sl_num]),np.min(resize_nii_CT[tt][sl_num]))
print(np.max(resize_nii_label[tt][sl_num]),np.min(resize_nii_label[tt][sl_num]))
# Out:
# t1ne CT nii image:
# 0.7955314827352742 0.0
# 0.5 0.0

# %%
from keras.layers import UpSampling3D, Conv3D, MaxPool3D, ReLU

def Conv3d(input, ch, f, pad= 'same', act = 'leakyrelu'):
    with tf.name_scope("Unet"):
        x = input
        x = Conv3D(ch, 3, padding = pad, use_bias=True)(x)
        if act == 'relu':
            x = tf.nn.relu(x)
        elif act == 'sigmoid':
            x = tf.sigmoid(x)
        elif act == 'leakyrelu':
            x = tf.nn.leaky_relu(x, alpha = 0.01)
        return x

def MaxPool3d(input, ps):
    x = input
    x = MaxPool3D(pool_size=ps, strides=ps)(x)
    return x

def Upsample3d(input, scale):
    x = input
    x = UpSampling3D(size = (scale,scale,scale), data_format ="channels_last")(x)
    return x

def Deconv3d(input, ch, upscale, batch, xdim, ydim, zdim, pad= 'SAME'):
    x = input
    x = Conv3DTranspose(x, filter=tf.constant(np.ones([upscale,upscale,upscale,ch,ch], np.float32)),
                               output_shape=[batch, xdim, ydim, zdim, ch],
                                strides=[1, upscale, upscale, upscale, 1],
                                padding= pad)
#     x = tf.layers.conv3d_transpose(x, ch, f, strides = [2,2,2], padding = pad, kernel_initializer=tf.contrib.layers.xavier_initializer(), use_bias=True)
    return x

def Unet(placeholders, batch):
    #decode
   
    x = placeholders['input']
    print("Input",x)
    x = Conv3d(x, 64, 3)
    x = Conv3d(x, 64, 3)
    conv1 = x
    x = MaxPool3d(x, 2)
    print("Conv1", conv1)
    
    x = Conv3d(x, 128, 3)
    x = Conv3d(x, 128, 3)
    conv2 = x
    x = MaxPool3d(x, 2)
    print("Conv2", conv2)
    
    x = Conv3d(x, 256, 3)
    x = Conv3d(x, 256, 3)
    conv3 = x
    x = MaxPool3d(x, 2)
    print("Conv3", conv3)
    
    x = Conv3d(x, 512, 3)
    x = Conv3d(x, 512, 3)
    conv4 = x
    x = MaxPool3d(x, 2)
    print("Conv4", conv4)
    
    #encode
    x = Conv3d(x, 512, 3)
    x = Conv3d(x, 512, 3)
    conv5 = x
    print("Conv5", conv5)
#     x = Deconv3d(x, 512, 2, batch, input_depth//8, input_height//8, input_width//8)
    x = Upsample3d(x,2)
    print("Upsample5", x)
    x = tf.concat([x, conv4], axis = 4)
    merge5 = x
    print("Merge5", merge5)
    
    x = Conv3d(x, 256, 3)
    x = Conv3d(x, 256, 3)
    conv6 = x
    print("Conv6", conv6)
#     x = Deconv3d(x, 256, 2, batch, input_depth//4, input_height//4, input_width//4)
    x = Upsample3d(x,2)
    x = tf.concat([x, conv3], axis = 4)
    merge6 = x
    print("Merge6", merge6)
    
    x = Conv3d(x, 128, 3)
    x = Conv3d(x, 128, 3)
    conv7 = x
    print("Conv7", conv7)
#     x = Deconv3d(x, 128, 2, batch, input_depth//2, input_height//2, input_width//2)
    x = Upsample3d(x,2)
    x = tf.concat([x, conv2], axis = 4)
    merge7 = x
    print("Merge7", merge7)
    
    x = Conv3d(x, 64, 3)
    x = Conv3d(x, 64, 3)
    conv8 = x
    print("Conv8", conv8)
#     x = Deconv3d(x, 64, 2, batch, input_depth, input_height, input_width)
    x = Upsample3d(x,2)
    x = tf.concat([x, conv1], axis = 4)
    merge8 = x
    print("Merge8", merge8)
    
    x = Conv3d(x, 32, 3)
    x = Conv3d(x, 32, 3)
    x = Conv3d(x, output_class_num, 1)
    conv9 = x
    print("Conv9", conv9)
    
    return x

# %%
placeholders = {
    'input': tf.placeholder(tf.float32,shape=(None,input_depth,input_height,input_width,1)),
    'label': tf.placeholder(tf.float32,shape=(None,input_depth,input_height,input_width,output_class_num))
}


#with tf.variable_scope('Unet_model') as scope:
Unet_out_tensor = Unet(placeholders, batch_size)
# Out:
# Input Tensor("Placeholder_4:0", shape=(?, 128, 128, 128, 1), dtype=float32)
# Conv1 Tensor("Unet_39/LeakyRelu:0", shape=(?, 128, 128, 128, 64), dtype=float32)
# Conv2 Tensor("Unet_41/LeakyRelu:0", shape=(?, 64, 64, 64, 128), dtype=float32)
# Conv3 Tensor("Unet_43/LeakyRelu:0", shape=(?, 32, 32, 32, 256), dtype=float32)
# Conv4 Tensor("Unet_45/LeakyRelu:0", shape=(?, 16, 16, 16, 512), dtype=float32)
# Conv5 Tensor("Unet_47/LeakyRelu:0", shape=(?, 8, 8, 8, 512), dtype=float32)
# Upsample5 Tensor("up_sampling3d_9/concat_2:0", shape=(?, 16, 16, 16, 512), dtype=float32)
# Merge5 Tensor("concat_8:0", shape=(?, 16, 16, 16, 1024), dtype=float32)
# Conv6 Tensor("Unet_49/LeakyRelu:0", shape=(?, 16, 16, 16, 256), dtype=float32)
# Merge6 Tensor("concat_9:0", shape=(?, 32, 32, 32, 512), dtype=float32)
# Conv7 Tensor("Unet_51/LeakyRelu:0", shape=(?, 32, 32, 32, 128), dtype=float32)
# Merge7 Tensor("concat_10:0", shape=(?, 64, 64, 64, 256), dtype=float32)
# Conv8 Tensor("Unet_53/LeakyRelu:0", shape=(?, 64, 64, 64, 64), dtype=float32)
# Merge8 Tensor("concat_11:0", shape=(?, 128, 128, 128, 128), dtype=float32)
# Conv9 Tensor("Unet_56/LeakyRelu:0", shape=(?, 128, 128, 128, 4), dtype=float32)

# %%
def focal_loss(pred, label):
    '''
    :param pred: B,N,num_class
    :param label: B,N
    :return: float
    '''
    label = tf.to_float(label)
    num_class = 4
    pred_soft = tf.nn.softmax(pred)
    #label_onehot = tf.one_hot(label, depth=num_class, dtype=tf.float32)
    probs = pred_soft * label  # (b, n, n_c)
    probs = tf.reduce_sum(probs, axis=-1)  # (b, n)
    focal_loss = -tf.pow((1-probs), 5.0) * tf.log(probs)
    loss = tf.reduce_mean(focal_loss)
    return loss

cross_entropy_loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=placeholders['label'],logits=Unet_out_tensor))

#bce = tf.keras.losses.BinaryCrossentropy()
#bce_loss = bce(placeholders['label'], Unet_out_tensor)
f_loss = focal_loss(Unet_out_tensor, placeholders['label'])

out_softmax = tf.nn.softmax(Unet_out_tensor)
softmax_label = tf.nn.softmax(placeholders['label'])
mse_loss = tf.losses.mean_squared_error(softmax_label,out_softmax)
#print(mse_loss.shape)
sub_value = softmax_label-out_softmax
#print(sub_value.shape)
a = sub_value[:,:,:,:,0]*0.05
b = sub_value[:,:,:,:,1]*0.15
c = sub_value[:,:,:,:,2]*0.2
d = sub_value[:,:,:,:,3]*0.6
weight_value = tf.stack([a, b, c, d], axis=-1)
weighted_mse_loss = tf.reduce_mean(weight_value**2)
#print(weighted_mse_loss.shape)
inse = tf.reduce_sum(out_softmax * softmax_label)
l = tf.reduce_sum(out_softmax)
r = tf.reduce_sum(softmax_label)
dice = (2. * inse + 1e-5) / (l + r + 1e-5)
dice = tf.reduce_mean(dice)
dice_loss = (1-dice)

loss = weighted_mse_loss

# %%
variables = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='Unet_model')
trainer = tf.train.AdamOptimizer(1e-4).minimize(loss)

# %%
saver = tf.train.Saver()
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
sess.run(tf.global_variables_initializer())
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device

# %%
data_3d = resize_nii_CT
label_3d = train_onehot_array 
print(label_3d.shape)

'''
data_3d=[]
label_3d=[]
for i in range(data.shape[0]//input_depth):
    for j in range(data.shape[1]//input_height):
        for k in range(data.shape[2]//input_width):
            data_3d.append(data[i*input_depth:(i+1)*input_depth,j*input_height:(j+1)*input_height,k*input_width:(k+1)*input_width])
            label_3d.append(label[i*input_depth:(i+1)*input_depth,j*input_height:(j+1)*input_height,k*input_width:(k+1)*input_width])

data_3d = np.asarray(data_3d)
label_3d = np.asarray(label_3d)
'''
print(data_3d.shape)
print(label_3d.shape)
# Out:
# (35, 128, 128, 128, 4)
# (35, 128, 128, 128)
# (35, 128, 128, 128, 4)

# %%
loss_list=[]
valid_loss_in_epoch = []
if isTrain:
    nowtime = time.time()
    for e in range(epoch):
        print("Epoch ",e," Current time: ", time.ctime())
        sel = np.arange((int)(data_3d.shape[0]/batch_size))
        np.random.shuffle(sel)
        iteration = (int)(data_3d.shape[0]/batch_size)
        loss_in_epoch = []            
        loss_v = []
        for it in range(iteration):

            input_batch = []
            label_batch = []
            for b in range(batch_size):
                input_batch.append(data_3d[sel[it*batch_size+b]])
                label_batch.append(label_3d[sel[it*batch_size+b]])
            input_batch = np.asarray(input_batch).reshape([batch_size,input_depth,input_height,input_width,1])
            label_batch = np.asarray(label_batch).reshape([batch_size,input_depth,input_height,input_width,output_class_num])

            feed_dict=dict()
            feed_dict.update({placeholders['input']:input_batch})
            feed_dict.update({placeholders['label']:label_batch})

            outs = sess.run([trainer, loss, Unet_out_tensor],feed_dict=feed_dict)
            
            cur_loss = outs[1]

            print("Epoch", e, "Iteration", it)
            print("Loss:", cur_loss)
            loss_in_epoch.append(cur_loss)
        loss_list.append(np.mean(loss_in_epoch))
        if(e%1==0):

            for i in range(valid_nii_CT.shape[0]):
            #         print("Testing batch ", i)

                input_batch = valid_nii_CT[i]  
                label_batch = valid_onehot_array[i]

                feed_dict=dict()
                feed_dict.update({placeholders['input']:input_batch.reshape(1,input_depth,input_height,input_width,1)})
                feed_dict.update({placeholders['label']:label_batch.reshape(1,input_depth,input_height,input_width,output_class_num)})
                # print valid loss
                outs = sess.run([loss, Unet_out_tensor],feed_dict=feed_dict)
                loss_v.append(outs[0])
                
            valid_loss_in_epoch.append(np.mean(loss_v))
            print("Valid loss: {}".format(np.mean(loss_v)))
            #logger.info("Valid loss: {loss_v}".format(loss_v = np.mean(valid_loss)))
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)
        saver.save(sess, "./"+checkpoint_dir+"/"+"Unet_epoch_"+str(e)+".ckpt")
# Out:
# Epoch  0  Current time:  Mon Jun 22 02:35:29 2020
# Epoch 0 Iteration 0
# Loss: 0.00064598175
# Epoch 0 Iteration 1
# Loss: 0.0006325554
# Epoch 0 Iteration 2
# Loss: 0.00062699296
# Epoch 0 Iteration 3
# Loss: 0.00062331074
# Epoch 0 Iteration 4
# Loss: 0.0006299728
# Epoch 0 Iteration 5
# Loss: 0.00063747424
# Epoch 0 Iteration 6
# Loss: 0.00060029887
# Epoch 0 Iteration 7
# Loss: 0.0005811566
# Epoch 0 Iteration 8
# Loss: 0.0005511186
# Epoch 0 Iteration 9
# Loss: 0.00050983083
# Epoch 0 Iteration 10
# Loss: 0.0005186463
# Epoch 0 Iteration 11
# Loss: 0.00053206075
# Epoch 0 Iteration 12
# Loss: 0.00042894098
# Epoch 0 Iteration 13
# Loss: 0.0005222785
# Epoch 0 Iteration 14
# Loss: 0.00039315567
# Epoch 0 Iteration 15
# Loss: 0.0003887012
# Epoch 0 Iteration 16
# Loss: 0.00030357568
# Epoch 0 Iteration 17
# Loss: 0.0005237708
# Epoch 0 Iteration 18
# Loss: 0.000247627
# Epoch 0 Iteration 19
# Loss: 0.0002664
# Epoch 0 Iteration 20
# Loss: 0.000272622
# Epoch 0 Iteration 21
# Loss: 0.00023850461
# Epoch 0 Iteration 22
# Loss: 0.00023625346
# Epoch 0 Iteration 23
# Loss: 0.00016355586
# Epoch 0 Iteration 24
# Loss: 0.00016837832
# Epoch 0 Iteration 25
# Loss: 0.00017762302
# Epoch 0 Iteration 26
# Loss: 0.0001094137
# Epoch 0 Iteration 27
# Loss: 0.00014710672
# Epoch 0 Iteration 28
# Loss: 0.00011555602
# Epoch 0 Iteration 29
# Loss: 0.000118277414
# Epoch 0 Iteration 30
# Loss: 8.051393e-05
# Epoch 0 Iteration 31
# Loss: 6.0393522e-05
# Epoch 0 Iteration 32
# Loss: 0.00013517909
# Epoch 0 Iteration 33
# Loss: 9.846227e-05
# Epoch 0 Iteration 34
# Loss: 7.075445e-05
# Valid loss: 6.303279951680452e-05
# Epoch  1  Current time:  Mon Jun 22 02:36:16 2020
# Epoch 1 Iteration 0
# Loss: 5.2370528e-05
# Epoch 1 Iteration 1
# Loss: 8.663018e-05
# Epoch 1 Iteration 2
# Loss: 5.974773e-05
# Epoch 1 Iteration 3
# Loss: 8.765095e-05
# Epoch 1 Iteration 4
# Loss: 7.2174276e-05
# Epoch 1 Iteration 5
# Loss: 5.285454e-05
# Epoch 1 Iteration 6
# Loss: 9.6822e-05
# Epoch 1 Iteration 7
# Loss: 0.00010795234
# Epoch 1 Iteration 8
# Loss: 6.5137036e-05
# Epoch 1 Iteration 9
# Loss: 9.474867e-05
# Epoch 1 Iteration 10
# Loss: 6.246874e-05
# Epoch 1 Iteration 11
# Loss: 5.4018805e-05
# Epoch 1 Iteration 12
# Loss: 4.7451085e-05
# Epoch 1 Iteration 13
# Loss: 5.223682e-05
# Epoch 1 Iteration 14
# Loss: 6.33034e-05
# Epoch 1 Iteration 15
# Loss: 4.3465334e-05
# Epoch 1 Iteration 16
# Loss: 3.6961093e-05
# Epoch 1 Iteration 17
# Loss: 3.8661783e-05
# Epoch 1 Iteration 18
# Loss: 6.856437e-05
# Epoch 1 Iteration 19
# Loss: 0.0001365424
# Epoch 1 Iteration 20
# Loss: 3.4390978e-05
# Epoch 1 Iteration 21
# Loss: 5.099965e-05
# Epoch 1 Iteration 22
# Loss: 4.8820344e-05
# Epoch 1 Iteration 23
# Loss: 8.171285e-05
# Epoch 1 Iteration 24
# Loss: 5.076095e-05
# Epoch 1 Iteration 25
# Loss: 6.120545e-05
# Epoch 1 Iteration 26
# Loss: 6.6967914e-05
# Epoch 1 Iteration 27
# Loss: 6.002407e-05
# Epoch 1 Iteration 28
# Loss: 3.681783e-05
# Epoch 1 Iteration 29
# Loss: 5.3896496e-05
# Epoch 1 Iteration 30
# Loss: 3.928537e-05
# Epoch 1 Iteration 31
# Loss: 2.423931e-05
# Epoch 1 Iteration 32
# Loss: 6.5693894e-05
# Epoch 1 Iteration 33
# Loss: 4.9869184e-05
# Epoch 1 Iteration 34
# Loss: 2.4611774e-05
# Valid loss: 3.5787303204415366e-05
# Epoch  2  Current time:  Mon Jun 22 02:37:02 2020
# Epoch 2 Iteration 0
# Loss: 4.5897108e-05
# Epoch 2 Iteration 1
# Loss: 4.1405252e-05
# Epoch 2 Iteration 2
# Loss: 0.00012754735
# Epoch 2 Iteration 3
# Loss: 4.9082053e-05
# Epoch 2 Iteration 4
# Loss: 3.6954305e-05
# Epoch 2 Iteration 5
# Loss: 2.8936121e-05
# Epoch 2 Iteration 6
# Loss: 2.9730307e-05
# Epoch 2 Iteration 7
# Loss: 4.129627e-05
# Epoch 2 Iteration 8
# Loss: 2.431128e-05
# Epoch 2 Iteration 9
# Loss: 7.379822e-05
# Epoch 2 Iteration 10
# Loss: 3.2814474e-05
# Epoch 2 Iteration 11
# Loss: 2.2849996e-05
# Epoch 2 Iteration 12
# Loss: 4.7950904e-05
# Epoch 2 Iteration 13
# Loss: 2.3397753e-05
# Epoch 2 Iteration 14
# Loss: 1.9045016e-05
# Epoch 2 Iteration 15
# Loss: 5.4684708e-05
# Epoch 2 Iteration 16
# Loss: 4.6993016e-05
# Epoch 2 Iteration 17
# Loss: 5.2442465e-05
# Epoch 2 Iteration 18
# Loss: 1.885406e-05
# Epoch 2 Iteration 19
# Loss: 6.824687e-05
# Epoch 2 Iteration 20
# Loss: 3.9399783e-05
# Epoch 2 Iteration 21
# Loss: 5.1143947e-05
# Epoch 2 Iteration 22
# Loss: 5.0505445e-05
# Epoch 2 Iteration 23
# Loss: 6.8166206e-05
# Epoch 2 Iteration 24
# Loss: 4.2040734e-05
# Epoch 2 Iteration 25
# Loss: 2.7490309e-05
# Epoch 2 Iteration 26
# Loss: 2.7239912e-05
# Epoch 2 Iteration 27
# Loss: 2.6423426e-05
# Epoch 2 Iteration 28
# Loss: 8.173399e-05
# Epoch 2 Iteration 29
# Loss: 5.5332275e-05
# Epoch 2 Iteration 30
# Loss: 5.8177327e-05
# Epoch 2 Iteration 31
# Loss: 3.1503052e-05
# Epoch 2 Iteration 32
# Loss: 1.405362e-05
# Epoch 2 Iteration 33
# Loss: 5.5596596e-05
# Epoch 2 Iteration 34
# Loss: 3.5871613e-05
# Valid loss: 2.7376736397854984e-05
# Epoch  3  Current time:  Mon Jun 22 02:37:48 2020
# Epoch 3 Iteration 0
# Loss: 4.2889274e-05
# Epoch 3 Iteration 1
# Loss: 4.0888655e-05
# Epoch 3 Iteration 2
# Loss: 2.212937e-05
# Epoch 3 Iteration 3
# Loss: 5.3691307e-05
# Epoch 3 Iteration 4
# Loss: 3.666528e-05
# Epoch 3 Iteration 5
# Loss: 4.2158914e-05
# Epoch 3 Iteration 6
# Loss: 4.727263e-05
# Epoch 3 Iteration 7
# Loss: 7.756094e-05
# Epoch 3 Iteration 8
# Loss: 3.142622e-05
# Epoch 3 Iteration 9
# Loss: 2.0761774e-05
# Epoch 3 Iteration 10
# Loss: 1.3996101e-05
# Epoch 3 Iteration 11
# Loss: 1.7544053e-05
# Epoch 3 Iteration 12
# Loss: 3.8582253e-05
# Epoch 3 Iteration 13
# Loss: 2.6059131e-05
# Epoch 3 Iteration 14
# Loss: 4.7473324e-05
# Epoch 3 Iteration 15
# Loss: 1.5610893e-05
# Epoch 3 Iteration 16
# Loss: 2.3950306e-05
# Epoch 3 Iteration 17
# Loss: 4.587514e-05
# Epoch 3 Iteration 18
# Loss: 5.511505e-05
# Epoch 3 Iteration 19
# Loss: 2.7126613e-05
# Epoch 3 Iteration 20
# Loss: 6.3742686e-05
# Epoch 3 Iteration 21
# Loss: 5.495597e-05
# Epoch 3 Iteration 22
# Loss: 6.2626044e-05
# Epoch 3 Iteration 23
# Loss: 4.4759872e-05
# Epoch 3 Iteration 24
# Loss: 2.198966e-05
# Epoch 3 Iteration 25
# Loss: 1.9099296e-05
# Epoch 3 Iteration 26
# Loss: 3.418133e-05
# Epoch 3 Iteration 27
# Loss: 1.4913103e-05
# Epoch 3 Iteration 28
# Loss: 0.00010493623
# Epoch 3 Iteration 29
# Loss: 3.0833515e-05
# Epoch 3 Iteration 30
# Loss: 3.2200187e-05
# Epoch 3 Iteration 31
# Loss: 1.09795055e-05
# Epoch 3 Iteration 32
# Loss: 5.6819677e-05
# Epoch 3 Iteration 33
# Loss: 1.9179814e-05
# Epoch 3 Iteration 34
# Loss: 1.6213124e-05
# Valid loss: 2.2525231543113478e-05
# Epoch  4  Current time:  Mon Jun 22 02:38:34 2020
# Epoch 4 Iteration 0
# Loss: 7.260093e-05
# Epoch 4 Iteration 1
# Loss: 1.8414905e-05
# Epoch 4 Iteration 2
# Loss: 4.9423943e-05
# Epoch 4 Iteration 3
# Loss: 3.2294425e-05
# Epoch 4 Iteration 4
# Loss: 1.112953e-05
# Epoch 4 Iteration 5
# Loss: 2.2532782e-05
# Epoch 4 Iteration 6
# Loss: 6.442371e-05
# Epoch 4 Iteration 7
# Loss: 6.0183393e-05
# Epoch 4 Iteration 8
# Loss: 2.7310223e-05
# Epoch 4 Iteration 9
# Loss: 3.4347864e-05
# Epoch 4 Iteration 10
# Loss: 5.3835705e-05
# Epoch 4 Iteration 11
# Loss: 4.328492e-05
# Epoch 4 Iteration 12
# Loss: 1.2502354e-05
# Epoch 4 Iteration 13
# Loss: 4.3478285e-05
# Epoch 4 Iteration 14
# Loss: 2.4756699e-05
# Epoch 4 Iteration 15
# Loss: 2.7548169e-05
# Epoch 4 Iteration 16
# Loss: 3.7155776e-05
# Epoch 4 Iteration 17
# Loss: 7.3610936e-06
# Epoch 4 Iteration 18
# Loss: 1.2549689e-05
# Epoch 4 Iteration 19
# Loss: 3.0937474e-05
# Epoch 4 Iteration 20
# Loss: 1.5699958e-05
# Epoch 4 Iteration 21
# Loss: 5.1109408e-05
# Epoch 4 Iteration 22
# Loss: 4.4212735e-05
# Epoch 4 Iteration 23
# Loss: 1.1941478e-05
# Epoch 4 Iteration 24
# Loss: 1.7179122e-05
# Epoch 4 Iteration 25
# Loss: 2.9309118e-05
# Epoch 4 Iteration 26
# Loss: 1.9360643e-05
# Epoch 4 Iteration 27
# Loss: 0.00010478129
# Epoch 4 Iteration 28
# Loss: 2.0044028e-05
# Epoch 4 Iteration 29
# Loss: 4.8598868e-05
# Epoch 4 Iteration 30
# Loss: 3.667675e-05
# Epoch 4 Iteration 31
# Loss: 2.7092367e-05
# Epoch 4 Iteration 32
# Loss: 3.9661656e-05
# Epoch 4 Iteration 33
# Loss: 1.0481978e-05
# Epoch 4 Iteration 34
# Loss: 3.3561853e-05
# Valid loss: 2.0945106371073052e-05
# Epoch  5  Current time:  Mon Jun 22 02:39:21 2020
# Epoch 5 Iteration 0
# Loss: 4.8029142e-05
# Epoch 5 Iteration 1
# Loss: 7.04588e-05
# Epoch 5 Iteration 2
# Loss: 3.3179662e-05
# Epoch 5 Iteration 3
# Loss: 3.8913997e-05
# Epoch 5 Iteration 4
# Loss: 3.0319847e-05
# Epoch 5 Iteration 5
# Loss: 9.928236e-05
# Epoch 5 Iteration 6
# Loss: 5.251772e-05
# Epoch 5 Iteration 7
# Loss: 4.3918542e-05
# Epoch 5 Iteration 8
# Loss: 8.528048e-06
# Epoch 5 Iteration 9
# Loss: 9.087618e-06
# Epoch 5 Iteration 10
# Loss: 1.4100027e-05
# Epoch 5 Iteration 11
# Loss: 4.187562e-05
# Epoch 5 Iteration 12
# Loss: 3.6303754e-05
# Epoch 5 Iteration 13
# Loss: 9.298586e-06
# Epoch 5 Iteration 14
# Loss: 2.6635973e-05
# Epoch 5 Iteration 15
# Loss: 1.10070505e-05
# Epoch 5 Iteration 16
# Loss: 2.3343968e-05
# Epoch 5 Iteration 17
# Loss: 1.6945813e-05
# Epoch 5 Iteration 18
# Loss: 1.5744285e-05
# Epoch 5 Iteration 19
# Loss: 6.202386e-05
# Epoch 5 Iteration 20
# Loss: 2.5206702e-05
# Epoch 5 Iteration 21
# Loss: 7.442998e-06
# Epoch 5 Iteration 22
# Loss: 4.0167874e-05
# Epoch 5 Iteration 23
# Loss: 1.787083e-05
# Epoch 5 Iteration 24
# Loss: 1.4917448e-05
# Epoch 5 Iteration 25
# Loss: 2.0360103e-05
# Epoch 5 Iteration 26
# Loss: 1.0155179e-05
# Epoch 5 Iteration 27
# Loss: 4.0470888e-05
# Epoch 5 Iteration 28
# Loss: 2.7598626e-05
# Epoch 5 Iteration 29
# Loss: 4.547025e-05
# Epoch 5 Iteration 30
# Loss: 4.6721234e-05
# Epoch 5 Iteration 31
# Loss: 5.8594665e-05
# Epoch 5 Iteration 32
# Loss: 3.1264808e-05
# Epoch 5 Iteration 33
# Loss: 1.6554677e-05
# Epoch 5 Iteration 34
# Loss: 2.6592208e-05
# Valid loss: 1.9205701391911134e-05
# Epoch  6  Current time:  Mon Jun 22 02:40:08 2020
# Epoch 6 Iteration 0
# Loss: 2.4716972e-05
# Epoch 6 Iteration 1
# Loss: 1.4275514e-05
# Epoch 6 Iteration 2
# Loss: 5.2431165e-05
# Epoch 6 Iteration 3
# Loss: 4.6801462e-05
# Epoch 6 Iteration 4
# Loss: 1.1317661e-05
# Epoch 6 Iteration 5
# Loss: 4.0055293e-05
# Epoch 6 Iteration 6
# Loss: 4.1679396e-05
# Epoch 6 Iteration 7
# Loss: 1.0077146e-05
# Epoch 6 Iteration 8
# Loss: 2.7648952e-05
# Epoch 6 Iteration 9
# Loss: 2.1099966e-05
# Epoch 6 Iteration 10
# Loss: 3.200047e-05
# Epoch 6 Iteration 11
# Loss: 4.5089622e-05
# Epoch 6 Iteration 12
# Loss: 3.2838987e-05
# Epoch 6 Iteration 13
# Loss: 2.6877015e-05
# Epoch 6 Iteration 14
# Loss: 1.6031345e-05
# Epoch 6 Iteration 15
# Loss: 1.6849624e-05
# Epoch 6 Iteration 16
# Loss: 6.9248645e-06
# Epoch 6 Iteration 17
# Loss: 5.7650126e-05
# Epoch 6 Iteration 18
# Loss: 4.7332072e-05
# Epoch 6 Iteration 19
# Loss: 1.1997408e-05
# Epoch 6 Iteration 20
# Loss: 2.7452801e-05
# Epoch 6 Iteration 21
# Loss: 7.07848e-06
# Epoch 6 Iteration 22
# Loss: 0.00010465718
# Epoch 6 Iteration 23
# Loss: 1.649013e-05
# Epoch 6 Iteration 24
# Loss: 2.8061637e-05
# Epoch 6 Iteration 25
# Loss: 2.1881722e-05
# Epoch 6 Iteration 26
# Loss: 3.3097633e-05
# Epoch 6 Iteration 27
# Loss: 3.912181e-05
# Epoch 6 Iteration 28
# Loss: 1.2543899e-05
# Epoch 6 Iteration 29
# Loss: 9.43844e-06
# Epoch 6 Iteration 30
# Loss: 6.588118e-05
# Epoch 6 Iteration 31
# Loss: 5.6154895e-05
# Epoch 6 Iteration 32
# Loss: 1.4365762e-05
# Epoch 6 Iteration 33
# Loss: 4.27024e-05
# Epoch 6 Iteration 34
# Loss: 3.5339854e-05
# Valid loss: 1.8261423974763602e-05
# Epoch  7  Current time:  Mon Jun 22 02:40:54 2020
# Epoch 7 Iteration 0
# Loss: 2.3337956e-05
# Epoch 7 Iteration 1
# Loss: 1.5134406e-05
# Epoch 7 Iteration 2
# Loss: 6.0201273e-05
# Epoch 7 Iteration 3
# Loss: 4.584431e-05
# Epoch 7 Iteration 4
# Loss: 1.3792558e-05
# Epoch 7 Iteration 5
# Loss: 2.0825137e-05
# Epoch 7 Iteration 6
# Loss: 5.8706584e-05
# Epoch 7 Iteration 7
# Loss: 4.199907e-05
# Epoch 7 Iteration 8
# Loss: 3.9239505e-05
# Epoch 7 Iteration 9
# Loss: 3.14943e-05
# Epoch 7 Iteration 10
# Loss: 5.720611e-06
# Epoch 7 Iteration 11
# Loss: 1.8761331e-05
# Epoch 7 Iteration 12
# Loss: 9.211044e-06
# Epoch 7 Iteration 13
# Loss: 6.769778e-06
# Epoch 7 Iteration 14
# Loss: 6.4235887e-06
# Epoch 7 Iteration 15
# Loss: 6.650651e-05
# Epoch 7 Iteration 16
# Loss: 1.4022167e-05
# Epoch 7 Iteration 17
# Loss: 2.3383545e-05
# Epoch 7 Iteration 18
# Loss: 1.376755e-05
# Epoch 7 Iteration 19
# Loss: 2.8238035e-05
# Epoch 7 Iteration 20
# Loss: 9.759313e-05
# Epoch 7 Iteration 21
# Loss: 3.842123e-05
# Epoch 7 Iteration 22
# Loss: 4.892377e-05
# Epoch 7 Iteration 23
# Loss: 2.8198192e-05
# Epoch 7 Iteration 24
# Loss: 5.764175e-05
# Epoch 7 Iteration 25
# Loss: 2.9525338e-05
# Epoch 7 Iteration 26
# Loss: 1.0984143e-05
# Epoch 7 Iteration 27
# Loss: 2.7226364e-05
# Epoch 7 Iteration 28
# Loss: 3.8066475e-05
# Epoch 7 Iteration 29
# Loss: 3.2569536e-05
# Epoch 7 Iteration 30
# Loss: 4.174453e-05
# Epoch 7 Iteration 31
# Loss: 4.6283538e-05
# Epoch 7 Iteration 32
# Loss: 1.8438588e-05
# Epoch 7 Iteration 33
# Loss: 7.4393165e-06
# Epoch 7 Iteration 34
# Loss: 3.5467026e-05
# Valid loss: 1.9376111595192924e-05
# Epoch  8  Current time:  Mon Jun 22 02:41:41 2020
# Epoch 8 Iteration 0
# Loss: 4.7288155e-05
# Epoch 8 Iteration 1
# Loss: 3.9751114e-05
# Epoch 8 Iteration 2
# Loss: 3.4030036e-05
# Epoch 8 Iteration 3
# Loss: 1.700977e-05
# Epoch 8 Iteration 4
# Loss: 1.4181934e-05
# Epoch 8 Iteration 5
# Loss: 2.1407537e-05
# Epoch 8 Iteration 6
# Loss: 2.8516042e-05
# Epoch 8 Iteration 7
# Loss: 1.2540465e-05
# Epoch 8 Iteration 8
# Loss: 3.936798e-05
# Epoch 8 Iteration 9
# Loss: 6.377833e-06
# Epoch 8 Iteration 10
# Loss: 1.2281286e-05
# Epoch 8 Iteration 11
# Loss: 4.1504027e-05
# Epoch 8 Iteration 12
# Loss: 1.4909457e-05
# Epoch 8 Iteration 13
# Loss: 7.734459e-06
# Epoch 8 Iteration 14
# Loss: 2.6100715e-05
# Epoch 8 Iteration 15
# Loss: 1.3531329e-05
# Epoch 8 Iteration 16
# Loss: 3.2178228e-05
# Epoch 8 Iteration 17
# Loss: 0.00010553235
# Epoch 8 Iteration 18
# Loss: 4.066981e-05
# Epoch 8 Iteration 19
# Loss: 2.447684e-05
# Epoch 8 Iteration 20
# Loss: 5.9959973e-05
# Epoch 8 Iteration 21
# Loss: 4.4838707e-06
# Epoch 8 Iteration 22
# Loss: 8.660555e-06
# Epoch 8 Iteration 23
# Loss: 3.3136097e-05
# Epoch 8 Iteration 24
# Loss: 5.287645e-05
# Epoch 8 Iteration 25
# Loss: 7.208514e-05
# Epoch 8 Iteration 26
# Loss: 5.7269e-05
# Epoch 8 Iteration 27
# Loss: 2.6825768e-05
# Epoch 8 Iteration 28
# Loss: 4.7551264e-05
# Epoch 8 Iteration 29
# Loss: 2.3970659e-05
# Epoch 8 Iteration 30
# Loss: 4.478339e-05
# Epoch 8 Iteration 31
# Loss: 9.120082e-06
# Epoch 8 Iteration 32
# Loss: 3.0475918e-05
# Epoch 8 Iteration 33
# Loss: 1.946657e-05
# Epoch 8 Iteration 34
# Loss: 5.3002877e-06
# Valid loss: 1.7934657080331817e-05
# Epoch  9  Current time:  Mon Jun 22 02:42:28 2020
# Epoch 9 Iteration 0
# Loss: 5.9060974e-05
# Epoch 9 Iteration 1
# Loss: 5.408071e-06
# Epoch 9 Iteration 2
# Loss: 4.4687906e-05
# Epoch 9 Iteration 3
# Loss: 5.6916087e-06
# Epoch 9 Iteration 4
# Loss: 3.3187844e-05
# Epoch 9 Iteration 5
# Loss: 2.6813817e-05
# Epoch 9 Iteration 6
# Loss: 5.207402e-05
# Epoch 9 Iteration 7
# Loss: 3.222148e-05
# Epoch 9 Iteration 8
# Loss: 1.41955215e-05
# Epoch 9 Iteration 9
# Loss: 5.879513e-05
# Epoch 9 Iteration 10
# Loss: 1.6098931e-05
# Epoch 9 Iteration 11
# Loss: 3.026299e-05
# Epoch 9 Iteration 12
# Loss: 2.5873323e-05
# Epoch 9 Iteration 13
# Loss: 2.7400009e-05
# Epoch 9 Iteration 14
# Loss: 8.457212e-06
# Epoch 9 Iteration 15
# Loss: 3.8997307e-05
# Epoch 9 Iteration 16
# Loss: 4.633718e-05
# Epoch 9 Iteration 17
# Loss: 4.5750363e-05
# Epoch 9 Iteration 18
# Loss: 1.3065048e-05
# Epoch 9 Iteration 19
# Loss: 0.00010226447
# Epoch 9 Iteration 20
# Loss: 6.951642e-05
# Epoch 9 Iteration 21
# Loss: 9.174661e-06
# Epoch 9 Iteration 22
# Loss: 7.0805518e-06
# Epoch 9 Iteration 23
# Loss: 2.3356424e-05
# Epoch 9 Iteration 24
# Loss: 3.884921e-05
# Epoch 9 Iteration 25
# Loss: 1.2772388e-05
# Epoch 9 Iteration 26
# Loss: 1.7744822e-05
# Epoch 9 Iteration 27
# Loss: 3.80932e-05
# Epoch 9 Iteration 28
# Loss: 6.7292194e-06
# Epoch 9 Iteration 29
# Loss: 2.0690479e-05
# Epoch 9 Iteration 30
# Loss: 1.1644952e-05
# Epoch 9 Iteration 31
# Loss: 3.3574564e-05
# Epoch 9 Iteration 32
# Loss: 1.4174119e-05
# Epoch 9 Iteration 33
# Loss: 4.1206487e-05
# Epoch 9 Iteration 34
# Loss: 2.32984e-05
# Valid loss: 1.7262653273064643e-05
# Epoch  10  Current time:  Mon Jun 22 02:43:14 2020
# Epoch 10 Iteration 0
# Loss: 0.00010595884
# Epoch 10 Iteration 1
# Loss: 2.1437207e-05
# Epoch 10 Iteration 2
# Loss: 3.0459534e-05
# Epoch 10 Iteration 3
# Loss: 3.243709e-05
# Epoch 10 Iteration 4
# Loss: 4.309301e-05
# Epoch 10 Iteration 5
# Loss: 2.7101316e-05
# Epoch 10 Iteration 6
# Loss: 1.8383824e-05
# Epoch 10 Iteration 7
# Loss: 3.6938796e-05
# Epoch 10 Iteration 8
# Loss: 1.3141475e-05
# Epoch 10 Iteration 9
# Loss: 3.8772858e-05
# Epoch 10 Iteration 10
# Loss: 1.5876629e-05
# Epoch 10 Iteration 11
# Loss: 1.4317508e-05
# Epoch 10 Iteration 12
# Loss: 1.14891545e-05
# Epoch 10 Iteration 13
# Loss: 2.2577688e-05
# Epoch 10 Iteration 14
# Loss: 2.2413595e-05
# Epoch 10 Iteration 15
# Loss: 5.1079616e-05
# Epoch 10 Iteration 16
# Loss: 4.437514e-05
# Epoch 10 Iteration 17
# Loss: 5.659914e-05
# Epoch 10 Iteration 18
# Loss: 1.2343206e-05
# Epoch 10 Iteration 19
# Loss: 4.359405e-06
# Epoch 10 Iteration 20
# Loss: 3.864739e-05
# Epoch 10 Iteration 21
# Loss: 1.3092698e-05
# Epoch 10 Iteration 22
# Loss: 7.965357e-06
# Epoch 10 Iteration 23
# Loss: 2.4986164e-05
# Epoch 10 Iteration 24
# Loss: 7.5049234e-06
# Epoch 10 Iteration 25
# Loss: 3.143798e-05
# Epoch 10 Iteration 26
# Loss: 5.731318e-05
# Epoch 10 Iteration 27
# Loss: 2.6354879e-05
# Epoch 10 Iteration 28
# Loss: 4.586644e-05
# Epoch 10 Iteration 29
# Loss: 9.090251e-06
# Epoch 10 Iteration 30
# Loss: 3.498632e-05
# Epoch 10 Iteration 31
# Loss: 6.389491e-06
# Epoch 10 Iteration 32
# Loss: 3.855147e-05
# Epoch 10 Iteration 33
# Loss: 7.057008e-05
# Epoch 10 Iteration 34
# Loss: 5.8989353e-06
# Valid loss: 1.7246196875930764e-05
# Epoch  11  Current time:  Mon Jun 22 02:44:01 2020
# Epoch 11 Iteration 0
# Loss: 1.7595747e-05
# Epoch 11 Iteration 1
# Loss: 1.6176982e-05
# Epoch 11 Iteration 2
# Loss: 2.2339882e-05
# Epoch 11 Iteration 3
# Loss: 4.5595505e-05
# Epoch 11 Iteration 4
# Loss: 7.357491e-06
# Epoch 11 Iteration 5
# Loss: 3.0386505e-05
# Epoch 11 Iteration 6
# Loss: 2.7666021e-05
# Epoch 11 Iteration 7
# Loss: 4.8594793e-06
# Epoch 11 Iteration 8
# Loss: 1.5016334e-05
# Epoch 11 Iteration 9
# Loss: 2.2396865e-05
# Epoch 11 Iteration 10
# Loss: 3.563543e-05
# Epoch 11 Iteration 11
# Loss: 2.4312076e-05
# Epoch 11 Iteration 12
# Loss: 2.5521971e-05
# Epoch 11 Iteration 13
# Loss: 7.592156e-06
# Epoch 11 Iteration 14
# Loss: 1.3293975e-05
# Epoch 11 Iteration 15
# Loss: 4.9155286e-05
# Epoch 11 Iteration 16
# Loss: 3.4681412e-05
# Epoch 11 Iteration 17
# Loss: 2.9905277e-05
# Epoch 11 Iteration 18
# Loss: 1.057358e-05
# Epoch 11 Iteration 19
# Loss: 5.668333e-05
# Epoch 11 Iteration 20
# Loss: 3.8097904e-05
# Epoch 11 Iteration 21
# Loss: 9.956925e-05
# Epoch 11 Iteration 22
# Loss: 8.058458e-06
# Epoch 11 Iteration 23
# Loss: 4.004724e-05
# Epoch 11 Iteration 24
# Loss: 5.4364784e-05
# Epoch 11 Iteration 25
# Loss: 2.9765539e-05
# Epoch 11 Iteration 26
# Loss: 3.674389e-05
# Epoch 11 Iteration 27
# Loss: 4.4652406e-05
# Epoch 11 Iteration 28
# Loss: 1.1811935e-05
# Epoch 11 Iteration 29
# Loss: 6.987766e-05
# Epoch 11 Iteration 30
# Loss: 1.3289095e-05
# Epoch 11 Iteration 31
# Loss: 1.8559429e-05
# Epoch 11 Iteration 32
# Loss: 1.2280998e-05
# Epoch 11 Iteration 33
# Loss: 2.8407974e-06
# Epoch 11 Iteration 34
# Loss: 4.4184082e-05
# Valid loss: 1.6933083315961994e-05
# Epoch  12  Current time:  Mon Jun 22 02:44:48 2020
# Epoch 12 Iteration 0
# Loss: 3.2652053e-05
# Epoch 12 Iteration 1
# Loss: 0.00010731508
# Epoch 12 Iteration 2
# Loss: 4.6916433e-05
# Epoch 12 Iteration 3
# Loss: 3.3054894e-05
# Epoch 12 Iteration 4
# Loss: 1.8068982e-05
# Epoch 12 Iteration 5
# Loss: 4.023853e-05
# Epoch 12 Iteration 6
# Loss: 2.7434538e-05
# Epoch 12 Iteration 7
# Loss: 6.9683188e-06
# Epoch 12 Iteration 8
# Loss: 4.0767944e-05
# Epoch 12 Iteration 9
# Loss: 1.5962014e-05
# Epoch 12 Iteration 10
# Loss: 3.3388278e-05
# Epoch 12 Iteration 11
# Loss: 1.2713287e-05
# Epoch 12 Iteration 12
# Loss: 2.0012978e-05
# Epoch 12 Iteration 13
# Loss: 2.9933315e-05
# Epoch 12 Iteration 14
# Loss: 2.2791066e-05
# Epoch 12 Iteration 15
# Loss: 1.1291552e-05
# Epoch 12 Iteration 16
# Loss: 5.814724e-05
# Epoch 12 Iteration 17
# Loss: 1.2315685e-05
# Epoch 12 Iteration 18
# Loss: 2.266174e-05
# Epoch 12 Iteration 19
# Loss: 4.6399757e-05
# Epoch 12 Iteration 20
# Loss: 3.7705053e-05
# Epoch 12 Iteration 21
# Loss: 7.893198e-06
# Epoch 12 Iteration 22
# Loss: 7.51012e-06
# Epoch 12 Iteration 23
# Loss: 4.423482e-06
# Epoch 12 Iteration 24
# Loss: 1.3011119e-05
# Epoch 12 Iteration 25
# Loss: 3.7876252e-05
# Epoch 12 Iteration 26
# Loss: 1.3484264e-05
# Epoch 12 Iteration 27
# Loss: 2.556353e-05
# Epoch 12 Iteration 28
# Loss: 5.691491e-05
# Epoch 12 Iteration 29
# Loss: 5.1199777e-06
# Epoch 12 Iteration 30
# Loss: 2.4788049e-05
# Epoch 12 Iteration 31
# Loss: 5.13775e-05
# Epoch 12 Iteration 32
# Loss: 6.9816575e-05
# Epoch 12 Iteration 33
# Loss: 4.2841657e-06
# Epoch 12 Iteration 34
# Loss: 4.271737e-05
# Valid loss: 1.6618036170257255e-05
# Epoch  13  Current time:  Mon Jun 22 02:45:34 2020
# Epoch 13 Iteration 0
# Loss: 2.5554917e-05
# Epoch 13 Iteration 1
# Loss: 0.000102289356
# Epoch 13 Iteration 2
# Loss: 6.965583e-05
# Epoch 13 Iteration 3
# Loss: 1.5666807e-05
# Epoch 13 Iteration 4
# Loss: 1.3018614e-05
# Epoch 13 Iteration 5
# Loss: 4.849737e-05
# Epoch 13 Iteration 6
# Loss: 5.4652965e-06
# Epoch 13 Iteration 7
# Loss: 1.6763172e-05
# Epoch 13 Iteration 8
# Loss: 5.478016e-05
# Epoch 13 Iteration 9
# Loss: 1.945118e-05
# Epoch 13 Iteration 10
# Loss: 3.341162e-05
# Epoch 13 Iteration 11
# Loss: 5.1362535e-05
# Epoch 13 Iteration 12
# Loss: 7.45102e-06
# Epoch 13 Iteration 13
# Loss: 2.5172254e-05
# Epoch 13 Iteration 14
# Loss: 1.2568922e-05
# Epoch 13 Iteration 15
# Loss: 3.0486812e-05
# Epoch 13 Iteration 16
# Loss: 3.6687485e-05
# Epoch 13 Iteration 17
# Loss: 2.196908e-05
# Epoch 13 Iteration 18
# Loss: 4.3857086e-05
# Epoch 13 Iteration 19
# Loss: 2.608231e-05
# Epoch 13 Iteration 20
# Loss: 3.6888967e-05
# Epoch 13 Iteration 21
# Loss: 3.9985484e-06
# Epoch 13 Iteration 22
# Loss: 3.7976744e-05
# Epoch 13 Iteration 23
# Loss: 1.8402798e-05
# Epoch 13 Iteration 24
# Loss: 5.5512905e-05
# Epoch 13 Iteration 25
# Loss: 5.858938e-06
# Epoch 13 Iteration 26
# Loss: 2.8813789e-05
# Epoch 13 Iteration 27
# Loss: 3.138315e-05
# Epoch 13 Iteration 28
# Loss: 1.4879415e-05
# Epoch 13 Iteration 29
# Loss: 2.1516158e-05
# Epoch 13 Iteration 30
# Loss: 4.274579e-05
# Epoch 13 Iteration 31
# Loss: 3.844987e-05
# Epoch 13 Iteration 32
# Loss: 7.339811e-06
# Epoch 13 Iteration 33
# Loss: 1.0454264e-05
# Epoch 13 Iteration 34
# Loss: 7.190505e-06
# Valid loss: 1.6488265828229487e-05
# Epoch  14  Current time:  Mon Jun 22 02:46:21 2020
# Epoch 14 Iteration 0
# Loss: 7.6664855e-06
# Epoch 14 Iteration 1
# Loss: 6.449605e-06
# Epoch 14 Iteration 2
# Loss: 5.954739e-05
# Epoch 14 Iteration 3
# Loss: 3.2632375e-05
# Epoch 14 Iteration 4
# Loss: 6.894489e-05
# Epoch 14 Iteration 5
# Loss: 2.9519491e-05
# Epoch 14 Iteration 6
# Loss: 2.4382178e-05
# Epoch 14 Iteration 7
# Loss: 1.4204124e-05
# Epoch 14 Iteration 8
# Loss: 4.5982933e-06
# Epoch 14 Iteration 9
# Loss: 0.00010157145
# Epoch 14 Iteration 10
# Loss: 3.7550337e-05
# Epoch 14 Iteration 11
# Loss: 1.4881046e-05
# Epoch 14 Iteration 12
# Loss: 1.0937784e-05
# Epoch 14 Iteration 13
# Loss: 3.355948e-05
# Epoch 14 Iteration 14
# Loss: 4.795278e-06
# Epoch 14 Iteration 15
# Loss: 4.605821e-05
# Epoch 14 Iteration 16
# Loss: 5.070927e-05
# Epoch 14 Iteration 17
# Loss: 5.585378e-05
# Epoch 14 Iteration 18
# Loss: 4.4899087e-05
# Epoch 14 Iteration 19
# Loss: 3.8237456e-05
# Epoch 14 Iteration 20
# Loss: 4.5420256e-06
# Epoch 14 Iteration 21
# Loss: 2.6558624e-05
# Epoch 14 Iteration 22
# Loss: 3.5001896e-05
# Epoch 14 Iteration 23
# Loss: 3.9058054e-05
# Epoch 14 Iteration 24
# Loss: 1.3602988e-05
# Epoch 14 Iteration 25
# Loss: 3.7116242e-05
# Epoch 14 Iteration 26
# Loss: 1.9049772e-05
# Epoch 14 Iteration 27
# Loss: 2.1589913e-05
# Epoch 14 Iteration 28
# Loss: 2.5341222e-05
# Epoch 14 Iteration 29
# Loss: 1.2116552e-05
# Epoch 14 Iteration 30
# Loss: 1.4552683e-05
# Epoch 14 Iteration 31
# Loss: 2.1747972e-05
# Epoch 14 Iteration 32
# Loss: 1.8940704e-05
# Epoch 14 Iteration 33
# Loss: 6.833586e-06
# Epoch 14 Iteration 34
# Loss: 4.1833704e-05
# Valid loss: 1.6896286979317665e-05
# Epoch  15  Current time:  Mon Jun 22 02:47:08 2020
# Epoch 15 Iteration 0
# Loss: 1.2732025e-05
# Epoch 15 Iteration 1
# Loss: 3.201815e-05
# Epoch 15 Iteration 2
# Loss: 2.6958185e-05
# Epoch 15 Iteration 3
# Loss: 2.2239621e-05
# Epoch 15 Iteration 4
# Loss: 3.0432471e-05
# Epoch 15 Iteration 5
# Loss: 1.8652678e-05
# Epoch 15 Iteration 6
# Loss: 1.3527272e-05
# Epoch 15 Iteration 7
# Loss: 2.5189585e-05
# Epoch 15 Iteration 8
# Loss: 3.8955372e-06
# Epoch 15 Iteration 9
# Loss: 1.2726261e-05
# Epoch 15 Iteration 10
# Loss: 4.8938335e-05
# Epoch 15 Iteration 11
# Loss: 4.3208343e-05
# Epoch 15 Iteration 12
# Loss: 6.4760693e-06
# Epoch 15 Iteration 13
# Loss: 3.718543e-05
# Epoch 15 Iteration 14
# Loss: 1.0415032e-05
# Epoch 15 Iteration 15
# Loss: 5.6265184e-05
# Epoch 15 Iteration 16
# Loss: 4.210812e-05
# Epoch 15 Iteration 17
# Loss: 1.2085959e-05
# Epoch 15 Iteration 18
# Loss: 3.171412e-05
# Epoch 15 Iteration 19
# Loss: 3.7171227e-05
# Epoch 15 Iteration 20
# Loss: 6.373789e-05
# Epoch 15 Iteration 21
# Loss: 8.473542e-06
# Epoch 15 Iteration 22
# Loss: 4.7054737e-06
# Epoch 15 Iteration 23
# Loss: 2.7414912e-05
# Epoch 15 Iteration 24
# Loss: 2.044476e-05
# Epoch 15 Iteration 25
# Loss: 4.7524827e-06
# Epoch 15 Iteration 26
# Loss: 3.4181357e-05
# Epoch 15 Iteration 27
# Loss: 3.563624e-05
# Epoch 15 Iteration 28
# Loss: 2.510802e-05
# Epoch 15 Iteration 29
# Loss: 9.669953e-05
# Epoch 15 Iteration 30
# Loss: 4.289844e-05
# Epoch 15 Iteration 31
# Loss: 1.7670423e-05
# Epoch 15 Iteration 32
# Loss: 7.3922206e-06
# Epoch 15 Iteration 33
# Loss: 5.712364e-05
# Epoch 15 Iteration 34
# Loss: 3.715968e-05
# Valid loss: 1.672941834840458e-05
# Epoch  16  Current time:  Mon Jun 22 02:47:54 2020
# Epoch 16 Iteration 0
# Loss: 2.8280836e-05
# Epoch 16 Iteration 1
# Loss: 1.2927147e-05
# Epoch 16 Iteration 2
# Loss: 4.8521106e-05
# Epoch 16 Iteration 3
# Loss: 4.9578917e-05
# Epoch 16 Iteration 4
# Loss: 2.6144746e-05
# Epoch 16 Iteration 5
# Loss: 4.2166736e-05
# Epoch 16 Iteration 6
# Loss: 4.1647336e-06
# Epoch 16 Iteration 7
# Loss: 1.9947674e-05
# Epoch 16 Iteration 8
# Loss: 2.5043537e-05
# Epoch 16 Iteration 9
# Loss: 1.2276759e-05
# Epoch 16 Iteration 10
# Loss: 5.457044e-05
# Epoch 16 Iteration 11
# Loss: 2.3300881e-05
# Epoch 16 Iteration 12
# Loss: 6.5235276e-05
# Epoch 16 Iteration 13
# Loss: 3.512481e-05
# Epoch 16 Iteration 14
# Loss: 1.3442978e-05
# Epoch 16 Iteration 15
# Loss: 1.9548761e-05
# Epoch 16 Iteration 16
# Loss: 3.2571246e-05
# Epoch 16 Iteration 17
# Loss: 4.5274595e-05
# Epoch 16 Iteration 18
# Loss: 4.1675983e-05
# Epoch 16 Iteration 19
# Loss: 7.069134e-06
# Epoch 16 Iteration 20
# Loss: 3.2758617e-05
# Epoch 16 Iteration 21
# Loss: 4.6651632e-05
# Epoch 16 Iteration 22
# Loss: 2.3972707e-06
# Epoch 16 Iteration 23
# Loss: 1.2258743e-05
# Epoch 16 Iteration 24
# Loss: 5.922511e-06
# Epoch 16 Iteration 25
# Loss: 6.551095e-06
# Epoch 16 Iteration 26
# Loss: 0.00010653535
# Epoch 16 Iteration 27
# Loss: 6.0236925e-06
# Epoch 16 Iteration 28
# Loss: 2.5356003e-05
# Epoch 16 Iteration 29
# Loss: 1.6316508e-05
# Epoch 16 Iteration 30
# Loss: 3.129807e-05
# Epoch 16 Iteration 31
# Loss: 1.7912815e-05
# Epoch 16 Iteration 32
# Loss: 1.7411592e-05
# Epoch 16 Iteration 33
# Loss: 3.586609e-05
# Epoch 16 Iteration 34
# Loss: 1.2102916e-05
# Valid loss: 1.733871795295272e-05
# Epoch  17  Current time:  Mon Jun 22 02:48:41 2020
# Epoch 17 Iteration 0
# Loss: 7.0466212e-06
# Epoch 17 Iteration 1
# Loss: 8.3453715e-06
# Epoch 17 Iteration 2
# Loss: 5.161107e-05
# Epoch 17 Iteration 3
# Loss: 7.382249e-05
# Epoch 17 Iteration 4
# Loss: 3.609584e-05
# Epoch 17 Iteration 5
# Loss: 3.330427e-05
# Epoch 17 Iteration 6
# Loss: 5.1149436e-05
# Epoch 17 Iteration 7
# Loss: 6.631023e-05
# Epoch 17 Iteration 8
# Loss: 4.97719e-05
# Epoch 17 Iteration 9
# Loss: 5.0120954e-05
# Epoch 17 Iteration 10
# Loss: 3.4396995e-05
# Epoch 17 Iteration 11
# Loss: 1.176865e-05
# Epoch 17 Iteration 12
# Loss: 1.2143867e-05
# Epoch 17 Iteration 13
# Loss: 1.6193979e-05
# Epoch 17 Iteration 14
# Loss: 3.0011579e-05
# Epoch 17 Iteration 15
# Loss: 3.0614043e-05
# Epoch 17 Iteration 16
# Loss: 5.8030666e-05
# Epoch 17 Iteration 17
# Loss: 1.3043506e-05
# Epoch 17 Iteration 18
# Loss: 8.365177e-06
# Epoch 17 Iteration 19
# Loss: 1.9978635e-05
# Epoch 17 Iteration 20
# Loss: 3.751897e-05
# Epoch 17 Iteration 21
# Loss: 2.7212887e-05
# Epoch 17 Iteration 22
# Loss: 9.8464925e-06
# Epoch 17 Iteration 23
# Loss: 1.005994e-05
# Epoch 17 Iteration 24
# Loss: 2.3372022e-05
# Epoch 17 Iteration 25
# Loss: 1.4794026e-05
# Epoch 17 Iteration 26
# Loss: 3.7905826e-05
# Epoch 17 Iteration 27
# Loss: 0.00010089278
# Epoch 17 Iteration 28
# Loss: 3.056838e-05
# Epoch 17 Iteration 29
# Loss: 1.5168362e-05
# Epoch 17 Iteration 30
# Loss: 4.408301e-05
# Epoch 17 Iteration 31
# Loss: 2.1193624e-05
# Epoch 17 Iteration 32
# Loss: 3.6197976e-05
# Epoch 17 Iteration 33
# Loss: 1.4921392e-05
# Epoch 17 Iteration 34
# Loss: 3.4892942e-05
# Valid loss: 1.8832610294339247e-05
# Epoch  18  Current time:  Mon Jun 22 02:49:28 2020
# Epoch 18 Iteration 0
# Loss: 3.221192e-05
# Epoch 18 Iteration 1
# Loss: 3.7315993e-05
# Epoch 18 Iteration 2
# Loss: 2.0575564e-05
# Epoch 18 Iteration 3
# Loss: 1.0894308e-05
# Epoch 18 Iteration 4
# Loss: 8.802297e-06
# Epoch 18 Iteration 5
# Loss: 6.9445587e-06
# Epoch 18 Iteration 6
# Loss: 2.8762064e-05
# Epoch 18 Iteration 7
# Loss: 4.6851845e-05
# Epoch 18 Iteration 8
# Loss: 1.3033053e-05
# Epoch 18 Iteration 9
# Loss: 5.5290024e-05
# Epoch 18 Iteration 10
# Loss: 4.948207e-06
# Epoch 18 Iteration 11
# Loss: 2.5463298e-05
# Epoch 18 Iteration 12
# Loss: 0.00010229394
# Epoch 18 Iteration 13
# Loss: 2.021678e-05
# Epoch 18 Iteration 14
# Loss: 4.3656128e-05
# Epoch 18 Iteration 15
# Loss: 2.1350288e-05
# Epoch 18 Iteration 16
# Loss: 6.41297e-06
# Epoch 18 Iteration 17
# Loss: 4.8716163e-05
# Epoch 18 Iteration 18
# Loss: 1.1799364e-05
# Epoch 18 Iteration 19
# Loss: 3.0064508e-05
# Epoch 18 Iteration 20
# Loss: 2.1061254e-05
# Epoch 18 Iteration 21
# Loss: 3.882935e-05
# Epoch 18 Iteration 22
# Loss: 3.1971158e-05
# Epoch 18 Iteration 23
# Loss: 5.8760783e-05
# Epoch 18 Iteration 24
# Loss: 2.4703544e-05
# Epoch 18 Iteration 25
# Loss: 1.4108067e-05
# Epoch 18 Iteration 26
# Loss: 1.3155914e-05
# Epoch 18 Iteration 27
# Loss: 3.5178626e-05
# Epoch 18 Iteration 28
# Loss: 1.2728971e-05
# Epoch 18 Iteration 29
# Loss: 4.8254227e-05
# Epoch 18 Iteration 30
# Loss: 5.6320664e-06
# Epoch 18 Iteration 31
# Loss: 1.542809e-05
# Epoch 18 Iteration 32
# Loss: 4.4576354e-05
# Epoch 18 Iteration 33
# Loss: 6.48335e-05
# Epoch 18 Iteration 34
# Loss: 2.557585e-05
# Valid loss: 1.684912967903074e-05
# Epoch  19  Current time:  Mon Jun 22 02:50:14 2020
# Epoch 19 Iteration 0
# Loss: 2.6372509e-05
# Epoch 19 Iteration 1
# Loss: 4.1063042e-05
# Epoch 19 Iteration 2
# Loss: 2.1126709e-05
# Epoch 19 Iteration 3
# Loss: 4.9909228e-05
# Epoch 19 Iteration 4
# Loss: 2.4701572e-05
# Epoch 19 Iteration 5
# Loss: 1.8168768e-05
# Epoch 19 Iteration 6
# Loss: 1.4504441e-05
# Epoch 19 Iteration 7
# Loss: 7.698312e-06
# Epoch 19 Iteration 8
# Loss: 1.1440172e-05
# Epoch 19 Iteration 9
# Loss: 1.1851082e-05
# Epoch 19 Iteration 10
# Loss: 3.852173e-06
# Epoch 19 Iteration 11
# Loss: 2.1240703e-05
# Epoch 19 Iteration 12
# Loss: 5.262246e-05
# Epoch 19 Iteration 13
# Loss: 9.332567e-05
# Epoch 19 Iteration 14
# Loss: 5.2598996e-05
# Epoch 19 Iteration 15
# Loss: 4.5721543e-05
# Epoch 19 Iteration 16
# Loss: 2.922763e-05
# Epoch 19 Iteration 17
# Loss: 4.6786143e-05
# Epoch 19 Iteration 18
# Loss: 3.292024e-05
# Epoch 19 Iteration 19
# Loss: 1.0670072e-05
# Epoch 19 Iteration 20
# Loss: 3.887895e-05
# Epoch 19 Iteration 21
# Loss: 1.5370468e-05
# Epoch 19 Iteration 22
# Loss: 6.528615e-05
# Epoch 19 Iteration 23
# Loss: 4.0137587e-05
# Epoch 19 Iteration 24
# Loss: 5.027614e-06
# Epoch 19 Iteration 25
# Loss: 4.934306e-06
# Epoch 19 Iteration 26
# Loss: 3.0417179e-05
# Epoch 19 Iteration 27
# Loss: 1.3992663e-05
# Epoch 19 Iteration 28
# Loss: 7.632793e-06
# Epoch 19 Iteration 29
# Loss: 1.6300111e-05
# Epoch 19 Iteration 30
# Loss: 5.818189e-05
# Epoch 19 Iteration 31
# Loss: 4.3393884e-05
# Epoch 19 Iteration 32
# Loss: 7.0841843e-06
# Epoch 19 Iteration 33
# Loss: 2.4635809e-05
# Epoch 19 Iteration 34
# Loss: 3.4960394e-05
# Valid loss: 1.6145580957527272e-05
# Epoch  20  Current time:  Mon Jun 22 02:51:01 2020
# Epoch 20 Iteration 0
# Loss: 3.120107e-05
# Epoch 20 Iteration 1
# Loss: 3.785735e-05
# Epoch 20 Iteration 2
# Loss: 4.6704e-06
# Epoch 20 Iteration 3
# Loss: 7.3189467e-06
# Epoch 20 Iteration 4
# Loss: 2.37877e-05
# Epoch 20 Iteration 5
# Loss: 5.3930245e-05
# Epoch 20 Iteration 6
# Loss: 4.3117274e-05
# Epoch 20 Iteration 7
# Loss: 4.3447202e-05
# Epoch 20 Iteration 8
# Loss: 4.4093285e-05
# Epoch 20 Iteration 9
# Loss: 3.4606383e-05
# Epoch 20 Iteration 10
# Loss: 2.549052e-05
# Epoch 20 Iteration 11
# Loss: 1.1352911e-05
# Epoch 20 Iteration 12
# Loss: 9.767884e-05
# Epoch 20 Iteration 13
# Loss: 3.6761576e-05
# Epoch 20 Iteration 14
# Loss: 2.2356733e-05
# Epoch 20 Iteration 15
# Loss: 4.259155e-06
# Epoch 20 Iteration 16
# Loss: 3.552402e-05
# Epoch 20 Iteration 17
# Loss: 4.9079135e-05
# Epoch 20 Iteration 18
# Loss: 1.3099803e-05
# Epoch 20 Iteration 19
# Loss: 6.5200884e-06
# Epoch 20 Iteration 20
# Loss: 2.1298001e-05
# Epoch 20 Iteration 21
# Loss: 1.3703114e-05
# Epoch 20 Iteration 22
# Loss: 2.7278349e-05
# Epoch 20 Iteration 23
# Loss: 6.2067855e-05
# Epoch 20 Iteration 24
# Loss: 5.565943e-05
# Epoch 20 Iteration 25
# Loss: 3.414449e-05
# Epoch 20 Iteration 26
# Loss: 1.2120468e-05
# Epoch 20 Iteration 27
# Loss: 2.7750211e-06
# Epoch 20 Iteration 28
# Loss: 1.0163221e-05
# Epoch 20 Iteration 29
# Loss: 3.125407e-05
# Epoch 20 Iteration 30
# Loss: 2.1813601e-05
# Epoch 20 Iteration 31
# Loss: 2.5701753e-05
# Epoch 20 Iteration 32
# Loss: 1.0978496e-05
# Epoch 20 Iteration 33
# Loss: 1.8625136e-05
# Epoch 20 Iteration 34
# Loss: 5.7687357e-06
# Valid loss: 1.6491112546646036e-05
# Epoch  21  Current time:  Mon Jun 22 02:51:48 2020
# Epoch 21 Iteration 0
# Loss: 2.5627403e-06
# Epoch 21 Iteration 1
# Loss: 6.737239e-06
# Epoch 21 Iteration 2
# Loss: 3.758196e-06
# Epoch 21 Iteration 3
# Loss: 3.6377038e-05
# Epoch 21 Iteration 4
# Loss: 7.718538e-06
# Epoch 21 Iteration 5
# Loss: 3.1984826e-05
# Epoch 21 Iteration 6
# Loss: 1.2622274e-05
# Epoch 21 Iteration 7
# Loss: 5.7341575e-05
# Epoch 21 Iteration 8
# Loss: 4.656351e-06
# Epoch 21 Iteration 9
# Loss: 9.934194e-05
# Epoch 21 Iteration 10
# Loss: 1.1013782e-05
# Epoch 21 Iteration 11
# Loss: 2.4244693e-05
# Epoch 21 Iteration 12
# Loss: 4.234243e-05
# Epoch 21 Iteration 13
# Loss: 1.43003235e-05
# Epoch 21 Iteration 14
# Loss: 4.729332e-05
# Epoch 21 Iteration 15
# Loss: 3.7049584e-05
# Epoch 21 Iteration 16
# Loss: 2.3164817e-05
# Epoch 21 Iteration 17
# Loss: 2.5989997e-05
# Epoch 21 Iteration 18
# Loss: 3.0691026e-05
# Epoch 21 Iteration 19
# Loss: 8.414092e-06
# Epoch 21 Iteration 20
# Loss: 1.1915858e-05
# Epoch 21 Iteration 21
# Loss: 4.1332976e-05
# Epoch 21 Iteration 22
# Loss: 4.7290203e-05
# Epoch 21 Iteration 23
# Loss: 5.571604e-05
# Epoch 21 Iteration 24
# Loss: 3.1175332e-05
# Epoch 21 Iteration 25
# Loss: 1.5566846e-05
# Epoch 21 Iteration 26
# Loss: 1.3398774e-05
# Epoch 21 Iteration 27
# Loss: 3.1724874e-05
# Epoch 21 Iteration 28
# Loss: 4.178063e-05
# Epoch 21 Iteration 29
# Loss: 1.7342645e-05
# Epoch 21 Iteration 30
# Loss: 1.7365017e-05
# Epoch 21 Iteration 31
# Loss: 6.3054074e-05
# Epoch 21 Iteration 32
# Loss: 2.169185e-05
# Epoch 21 Iteration 33
# Loss: 2.025865e-05
# Epoch 21 Iteration 34
# Loss: 4.6604706e-05
# Valid loss: 1.7355876479996368e-05
# Epoch  22  Current time:  Mon Jun 22 02:52:34 2020
# Epoch 22 Iteration 0
# Loss: 2.9510815e-05
# Epoch 22 Iteration 1
# Loss: 2.4498775e-05
# Epoch 22 Iteration 2
# Loss: 2.3793182e-05
# Epoch 22 Iteration 3
# Loss: 4.010069e-05
# Epoch 22 Iteration 4
# Loss: 1.9881394e-05
# Epoch 22 Iteration 5
# Loss: 1.2026661e-05
# Epoch 22 Iteration 6
# Loss: 3.930215e-05
# Epoch 22 Iteration 7
# Loss: 6.8308414e-05
# Epoch 22 Iteration 8
# Loss: 1.7230059e-05
# Epoch 22 Iteration 9
# Loss: 5.799954e-05
# Epoch 22 Iteration 10
# Loss: 5.8098725e-05
# Epoch 22 Iteration 11
# Loss: 1.3238364e-05
# Epoch 22 Iteration 12
# Loss: 4.8958555e-06
# Epoch 22 Iteration 13
# Loss: 4.074747e-06
# Epoch 22 Iteration 14
# Loss: 1.9165538e-05
# Epoch 22 Iteration 15
# Loss: 2.4283885e-05
# Epoch 22 Iteration 16
# Loss: 0.00010327838
# Epoch 22 Iteration 17
# Loss: 1.1813291e-05
# Epoch 22 Iteration 18
# Loss: 3.8059923e-05
# Epoch 22 Iteration 19
# Loss: 3.1713207e-05
# Epoch 22 Iteration 20
# Loss: 3.2053995e-05
# Epoch 22 Iteration 21
# Loss: 1.4820345e-05
# Epoch 22 Iteration 22
# Loss: 3.4912013e-05
# Epoch 22 Iteration 23
# Loss: 8.608934e-06
# Epoch 22 Iteration 24
# Loss: 4.7387606e-05
# Epoch 22 Iteration 25
# Loss: 4.124487e-05
# Epoch 22 Iteration 26
# Loss: 2.4409208e-05
# Epoch 22 Iteration 27
# Loss: 3.9335255e-06
# Epoch 22 Iteration 28
# Loss: 7.3433303e-06
# Epoch 22 Iteration 29
# Loss: 4.3606782e-05
# Epoch 22 Iteration 30
# Loss: 4.3774868e-05
# Epoch 22 Iteration 31
# Loss: 2.9877177e-05
# Epoch 22 Iteration 32
# Loss: 1.1354927e-05
# Epoch 22 Iteration 33
# Loss: 2.0740436e-05
# Epoch 22 Iteration 34
# Loss: 6.425896e-06
# Valid loss: 1.5775280189700425e-05
# Epoch  23  Current time:  Mon Jun 22 02:53:21 2020
# Epoch 23 Iteration 0
# Loss: 3.749623e-05
# Epoch 23 Iteration 1
# Loss: 7.140028e-06
# Epoch 23 Iteration 2
# Loss: 4.648685e-05
# Epoch 23 Iteration 3
# Loss: 2.0637377e-05
# Epoch 23 Iteration 4
# Loss: 6.459885e-06
# Epoch 23 Iteration 5
# Loss: 2.7998285e-05
# Epoch 23 Iteration 6
# Loss: 1.29071595e-05
# Epoch 23 Iteration 7
# Loss: 3.9575694e-05
# Epoch 23 Iteration 8
# Loss: 3.837035e-05
# Epoch 23 Iteration 9
# Loss: 1.1408972e-05
# Epoch 23 Iteration 10
# Loss: 5.6105957e-05
# Epoch 23 Iteration 11
# Loss: 2.4734956e-05
# Epoch 23 Iteration 12
# Loss: 1.3585853e-05
# Epoch 23 Iteration 13
# Loss: 1.401967e-05
# Epoch 23 Iteration 14
# Loss: 3.2096323e-05
# Epoch 23 Iteration 15
# Loss: 1.0615805e-05
# Epoch 23 Iteration 16
# Loss: 2.0393223e-05
# Epoch 23 Iteration 17
# Loss: 3.1418946e-05
# Epoch 23 Iteration 18
# Loss: 7.420259e-06
# Epoch 23 Iteration 19
# Loss: 2.9660772e-05
# Epoch 23 Iteration 20
# Loss: 9.7679964e-05
# Epoch 23 Iteration 21
# Loss: 3.5588837e-05
# Epoch 23 Iteration 22
# Loss: 3.3187505e-05
# Epoch 23 Iteration 23
# Loss: 1.223237e-05
# Epoch 23 Iteration 24
# Loss: 1.7600241e-05
# Epoch 23 Iteration 25
# Loss: 2.3090364e-05
# Epoch 23 Iteration 26
# Loss: 4.0150935e-06
# Epoch 23 Iteration 27
# Loss: 2.4614606e-05
# Epoch 23 Iteration 28
# Loss: 4.649863e-05
# Epoch 23 Iteration 29
# Loss: 7.168981e-05
# Epoch 23 Iteration 30
# Loss: 5.29044e-05
# Epoch 23 Iteration 31
# Loss: 7.13578e-06
# Epoch 23 Iteration 32
# Loss: 3.390827e-06
# Epoch 23 Iteration 33
# Loss: 1.6137103e-05
# Epoch 23 Iteration 34
# Loss: 4.7509115e-05
# Valid loss: 1.841046650952194e-05
# Epoch  24  Current time:  Mon Jun 22 02:54:08 2020
# Epoch 24 Iteration 0
# Loss: 1.4285655e-05
# Epoch 24 Iteration 1
# Loss: 1.6174741e-05
# Epoch 24 Iteration 2
# Loss: 3.32335e-05
# Epoch 24 Iteration 3
# Loss: 2.7695789e-05
# Epoch 24 Iteration 4
# Loss: 4.310385e-06
# Epoch 24 Iteration 5
# Loss: 7.6960005e-06
# Epoch 24 Iteration 6
# Loss: 3.11112e-05
# Epoch 24 Iteration 7
# Loss: 0.00010765578
# Epoch 24 Iteration 8
# Loss: 3.35425e-05
# Epoch 24 Iteration 9
# Loss: 5.969131e-05
# Epoch 24 Iteration 10
# Loss: 3.888304e-05
# Epoch 24 Iteration 11
# Loss: 4.8640064e-05
# Epoch 24 Iteration 12
# Loss: 3.797939e-05
# Epoch 24 Iteration 13
# Loss: 2.7100818e-05
# Epoch 24 Iteration 14
# Loss: 7.5051184e-06
# Epoch 24 Iteration 15
# Loss: 2.6477562e-06
# Epoch 24 Iteration 16
# Loss: 3.848313e-05
# Epoch 24 Iteration 17
# Loss: 4.4231114e-05
# Epoch 24 Iteration 18
# Loss: 4.871495e-06
# Epoch 24 Iteration 19
# Loss: 1.3043087e-05
# Epoch 24 Iteration 20
# Loss: 5.3082294e-05
# Epoch 24 Iteration 21
# Loss: 1.7025512e-05
# Epoch 24 Iteration 22
# Loss: 2.4808494e-05
# Epoch 24 Iteration 23
# Loss: 3.098556e-05
# Epoch 24 Iteration 24
# Loss: 4.385308e-05
# Epoch 24 Iteration 25
# Loss: 3.951529e-05
# Epoch 24 Iteration 26
# Loss: 1.1303471e-05
# Epoch 24 Iteration 27
# Loss: 2.2347764e-05
# Epoch 24 Iteration 28
# Loss: 6.4175047e-06
# Epoch 24 Iteration 29
# Loss: 7.1688824e-05
# Epoch 24 Iteration 30
# Loss: 1.1361126e-05
# Epoch 24 Iteration 31
# Loss: 1.9795534e-05
# Epoch 24 Iteration 32
# Loss: 5.621734e-05
# Epoch 24 Iteration 33
# Loss: 1.3375086e-05
# Epoch 24 Iteration 34
# Loss: 2.1825943e-05
# Valid loss: 1.6431742551503703e-05
# Epoch  25  Current time:  Mon Jun 22 02:54:55 2020
# Epoch 25 Iteration 0
# Loss: 4.8709603e-06
# Epoch 25 Iteration 1
# Loss: 4.037579e-06
# Epoch 25 Iteration 2
# Loss: 6.745978e-06
# Epoch 25 Iteration 3
# Loss: 1.0506801e-05
# Epoch 25 Iteration 4
# Loss: 1.653093e-05
# Epoch 25 Iteration 5
# Loss: 2.5675432e-05
# Epoch 25 Iteration 6
# Loss: 3.215091e-05
# Epoch 25 Iteration 7
# Loss: 2.9645056e-05
# Epoch 25 Iteration 8
# Loss: 2.4520084e-05
# Epoch 25 Iteration 9
# Loss: 2.1481459e-05
# Epoch 25 Iteration 10
# Loss: 3.759267e-05
# Epoch 25 Iteration 11
# Loss: 0.00010097081
# Epoch 25 Iteration 12
# Loss: 5.4707954e-05
# Epoch 25 Iteration 13
# Loss: 3.242263e-05
# Epoch 25 Iteration 14
# Loss: 3.8111324e-05
# Epoch 25 Iteration 15
# Loss: 3.745188e-05
# Epoch 25 Iteration 16
# Loss: 5.6388344e-05
# Epoch 25 Iteration 17
# Loss: 5.1187155e-05
# Epoch 25 Iteration 18
# Loss: 2.3036318e-05
# Epoch 25 Iteration 19
# Loss: 2.0446847e-05
# Epoch 25 Iteration 20
# Loss: 2.660342e-05
# Epoch 25 Iteration 21
# Loss: 5.1348243e-06
# Epoch 25 Iteration 22
# Loss: 1.3452442e-05
# Epoch 25 Iteration 23
# Loss: 3.7441892e-05
# Epoch 25 Iteration 24
# Loss: 4.4127457e-05
# Epoch 25 Iteration 25
# Loss: 3.2086726e-05
# Epoch 25 Iteration 26
# Loss: 8.107895e-06
# Epoch 25 Iteration 27
# Loss: 1.2783101e-05
# Epoch 25 Iteration 28
# Loss: 1.4848368e-05
# Epoch 25 Iteration 29
# Loss: 7.6117512e-06
# Epoch 25 Iteration 30
# Loss: 2.274068e-05
# Epoch 25 Iteration 31
# Loss: 1.6067532e-05
# Epoch 25 Iteration 32
# Loss: 4.3393593e-05
# Epoch 25 Iteration 33
# Loss: 4.7607777e-05
# Epoch 25 Iteration 34
# Loss: 7.158457e-05
# Valid loss: 1.6304069504258223e-05
# Epoch  26  Current time:  Mon Jun 22 02:55:41 2020
# Epoch 26 Iteration 0
# Loss: 3.83761e-06
# Epoch 26 Iteration 1
# Loss: 1.2414405e-05
# Epoch 26 Iteration 2
# Loss: 2.4436245e-05
# Epoch 26 Iteration 3
# Loss: 6.965955e-06
# Epoch 26 Iteration 4
# Loss: 7.3581637e-06
# Epoch 26 Iteration 5
# Loss: 2.9346613e-05
# Epoch 26 Iteration 6
# Loss: 5.643232e-05
# Epoch 26 Iteration 7
# Loss: 4.0444465e-06
# Epoch 26 Iteration 8
# Loss: 0.000100794015
# Epoch 26 Iteration 9
# Loss: 1.094046e-05
# Epoch 26 Iteration 10
# Loss: 1.2143297e-05
# Epoch 26 Iteration 11
# Loss: 5.5612025e-05
# Epoch 26 Iteration 12
# Loss: 4.815145e-06
# Epoch 26 Iteration 13
# Loss: 4.5196473e-05
# Epoch 26 Iteration 14
# Loss: 3.2897915e-05
# Epoch 26 Iteration 15
# Loss: 3.7050082e-05
# Epoch 26 Iteration 16
# Loss: 3.626864e-05
# Epoch 26 Iteration 17
# Loss: 7.5689186e-06
# Epoch 26 Iteration 18
# Loss: 3.784627e-05
# Epoch 26 Iteration 19
# Loss: 2.9476112e-05
# Epoch 26 Iteration 20
# Loss: 3.8599144e-05
# Epoch 26 Iteration 21
# Loss: 4.2782285e-05
# Epoch 26 Iteration 22
# Loss: 6.855167e-05
# Epoch 26 Iteration 23
# Loss: 1.2963987e-05
# Epoch 26 Iteration 24
# Loss: 1.873807e-05
# Epoch 26 Iteration 25
# Loss: 4.961553e-05
# Epoch 26 Iteration 26
# Loss: 2.0829568e-05
# Epoch 26 Iteration 27
# Loss: 1.1358855e-05
# Epoch 26 Iteration 28
# Loss: 3.0508127e-05
# Epoch 26 Iteration 29
# Loss: 2.3978759e-05
# Epoch 26 Iteration 30
# Loss: 2.043855e-05
# Epoch 26 Iteration 31
# Loss: 4.510754e-05
# Epoch 26 Iteration 32
# Loss: 1.795118e-05
# Epoch 26 Iteration 33
# Loss: 1.4286996e-05
# Epoch 26 Iteration 34
# Loss: 2.4817786e-05
# Valid loss: 1.603008058737032e-05
# Epoch  27  Current time:  Mon Jun 22 02:56:28 2020
# Epoch 27 Iteration 0
# Loss: 1.1468568e-05
# Epoch 27 Iteration 1
# Loss: 1.8228568e-05
# Epoch 27 Iteration 2
# Loss: 2.3510653e-05
# Epoch 27 Iteration 3
# Loss: 2.1014315e-05
# Epoch 27 Iteration 4
# Loss: 2.5098578e-05
# Epoch 27 Iteration 5
# Loss: 1.2271015e-05
# Epoch 27 Iteration 6
# Loss: 2.8030954e-05
# Epoch 27 Iteration 7
# Loss: 3.5911016e-05
# Epoch 27 Iteration 8
# Loss: 6.8930253e-06
# Epoch 27 Iteration 9
# Loss: 3.293485e-05
# Epoch 27 Iteration 10
# Loss: 2.0102318e-05
# Epoch 27 Iteration 11
# Loss: 4.191144e-05
# Epoch 27 Iteration 12
# Loss: 2.279368e-05
# Epoch 27 Iteration 13
# Loss: 2.9652401e-05
# Epoch 27 Iteration 14
# Loss: 2.8006958e-05
# Epoch 27 Iteration 15
# Loss: 1.1620542e-05
# Epoch 27 Iteration 16
# Loss: 3.5454086e-06
# Epoch 27 Iteration 17
# Loss: 5.129038e-06
# Epoch 27 Iteration 18
# Loss: 7.289549e-06
# Epoch 27 Iteration 19
# Loss: 0.00010394448
# Epoch 27 Iteration 20
# Loss: 5.7999023e-05
# Epoch 27 Iteration 21
# Loss: 3.3674693e-05
# Epoch 27 Iteration 22
# Loss: 3.1900112e-05
# Epoch 27 Iteration 23
# Loss: 4.3104237e-06
# Epoch 27 Iteration 24
# Loss: 7.4891855e-06
# Epoch 27 Iteration 25
# Loss: 5.674783e-05
# Epoch 27 Iteration 26
# Loss: 3.7007267e-05
# Epoch 27 Iteration 27
# Loss: 4.3062682e-05
# Epoch 27 Iteration 28
# Loss: 1.5267271e-05
# Epoch 27 Iteration 29
# Loss: 1.0105414e-05
# Epoch 27 Iteration 30
# Loss: 3.9714047e-05
# Epoch 27 Iteration 31
# Loss: 4.4694738e-05
# Epoch 27 Iteration 32
# Loss: 4.7944857e-05
# Epoch 27 Iteration 33
# Loss: 6.553685e-05
# Epoch 27 Iteration 34
# Loss: 1.9449923e-05
# Valid loss: 1.5834673831705004e-05
# Epoch  28  Current time:  Mon Jun 22 02:57:15 2020
# Epoch 28 Iteration 0
# Loss: 4.3453114e-05
# Epoch 28 Iteration 1
# Loss: 4.11989e-05
# Epoch 28 Iteration 2
# Loss: 5.7874924e-05
# Epoch 28 Iteration 3
# Loss: 6.326487e-05
# Epoch 28 Iteration 4
# Loss: 2.92569e-05
# Epoch 28 Iteration 5
# Loss: 1.4265219e-05
# Epoch 28 Iteration 6
# Loss: 2.1358308e-05
# Epoch 28 Iteration 7
# Loss: 2.3049986e-05
# Epoch 28 Iteration 8
# Loss: 1.8986624e-05
# Epoch 28 Iteration 9
# Loss: 3.7337966e-05
# Epoch 28 Iteration 10
# Loss: 4.1485895e-05
# Epoch 28 Iteration 11
# Loss: 4.6589514e-05
# Epoch 28 Iteration 12
# Loss: 5.529917e-06
# Epoch 28 Iteration 13
# Loss: 1.9378516e-05
# Epoch 28 Iteration 14
# Loss: 1.0019918e-05
# Epoch 28 Iteration 15
# Loss: 1.77457e-05
# Epoch 28 Iteration 16
# Loss: 3.2454103e-05
# Epoch 28 Iteration 17
# Loss: 1.161265e-05
# Epoch 28 Iteration 18
# Loss: 0.00010141667
# Epoch 28 Iteration 19
# Loss: 3.2444725e-05
# Epoch 28 Iteration 20
# Loss: 4.924377e-05
# Epoch 28 Iteration 21
# Loss: 3.833795e-06
# Epoch 28 Iteration 22
# Loss: 8.287906e-06
# Epoch 28 Iteration 23
# Loss: 5.7804664e-05
# Epoch 28 Iteration 24
# Loss: 2.5161446e-05
# Epoch 28 Iteration 25
# Loss: 1.4149051e-05
# Epoch 28 Iteration 26
# Loss: 8.155118e-06
# Epoch 28 Iteration 27
# Loss: 3.3387874e-05
# Epoch 28 Iteration 28
# Loss: 1.2230297e-05
# Epoch 28 Iteration 29
# Loss: 3.4922145e-05
# Epoch 28 Iteration 30
# Loss: 3.5989928e-05
# Epoch 28 Iteration 31
# Loss: 1.0099211e-05
# Epoch 28 Iteration 32
# Loss: 1.437356e-05
# Epoch 28 Iteration 33
# Loss: 2.417206e-05
# Epoch 28 Iteration 34
# Loss: 4.4923872e-06
# Valid loss: 1.5992372937034816e-05
# Epoch  29  Current time:  Mon Jun 22 02:58:02 2020
# Epoch 29 Iteration 0
# Loss: 1.0547236e-05
# Epoch 29 Iteration 1
# Loss: 1.3934888e-05
# Epoch 29 Iteration 2
# Loss: 1.4277188e-05
# Epoch 29 Iteration 3
# Loss: 1.2199216e-05
# Epoch 29 Iteration 4
# Loss: 5.5736466e-05
# Epoch 29 Iteration 5
# Loss: 1.2900613e-05
# Epoch 29 Iteration 6
# Loss: 5.3588055e-06
# Epoch 29 Iteration 7
# Loss: 3.708509e-05
# Epoch 29 Iteration 8
# Loss: 3.859793e-05
# Epoch 29 Iteration 9
# Loss: 6.4753367e-06
# Epoch 29 Iteration 10
# Loss: 4.65639e-05
# Epoch 29 Iteration 11
# Loss: 4.253059e-05
# Epoch 29 Iteration 12
# Loss: 4.4363747e-05
# Epoch 29 Iteration 13
# Loss: 6.847085e-06
# Epoch 29 Iteration 14
# Loss: 2.958553e-05
# Epoch 29 Iteration 15
# Loss: 3.0656156e-05
# Epoch 29 Iteration 16
# Loss: 2.6534088e-05
# Epoch 29 Iteration 17
# Loss: 2.0019646e-05
# Epoch 29 Iteration 18
# Loss: 4.8801656e-05
# Epoch 29 Iteration 19
# Loss: 3.40692e-05
# Epoch 29 Iteration 20
# Loss: 9.716436e-05
# Epoch 29 Iteration 21
# Loss: 1.1844903e-05
# Epoch 29 Iteration 22
# Loss: 3.637926e-05
# Epoch 29 Iteration 23
# Loss: 1.8698807e-05
# Epoch 29 Iteration 24
# Loss: 5.3528503e-05
# Epoch 29 Iteration 25
# Loss: 2.4899979e-05
# Epoch 29 Iteration 26
# Loss: 2.0569303e-05
# Epoch 29 Iteration 27
# Loss: 2.4374578e-05
# Epoch 29 Iteration 28
# Loss: 3.7976706e-06
# Epoch 29 Iteration 29
# Loss: 1.6571314e-05
# Epoch 29 Iteration 30
# Loss: 3.305935e-05
# Epoch 29 Iteration 31
# Loss: 4.1779367e-06
# Epoch 29 Iteration 32
# Loss: 2.2586133e-05
# Epoch 29 Iteration 33
# Loss: 6.848233e-06
# Epoch 29 Iteration 34
# Loss: 6.3828455e-05
# Valid loss: 1.538740070827771e-05
# Epoch  30  Current time:  Mon Jun 22 02:58:48 2020
# Epoch 30 Iteration 0
# Loss: 2.4105659e-05
# Epoch 30 Iteration 1
# Loss: 1.9999363e-05
# Epoch 30 Iteration 2
# Loss: 4.255158e-05
# Epoch 30 Iteration 3
# Loss: 7.0980423e-06
# Epoch 30 Iteration 4
# Loss: 1.02964905e-05
# Epoch 30 Iteration 5
# Loss: 4.4097333e-06
# Epoch 30 Iteration 6
# Loss: 2.2941565e-05
# Epoch 30 Iteration 7
# Loss: 3.6115172e-05
# Epoch 30 Iteration 8
# Loss: 1.7960112e-05
# Epoch 30 Iteration 9
# Loss: 2.9610832e-05
# Epoch 30 Iteration 10
# Loss: 4.6374143e-06
# Epoch 30 Iteration 11
# Loss: 5.919415e-05
# Epoch 30 Iteration 12
# Loss: 3.901175e-05
# Epoch 30 Iteration 13
# Loss: 4.9678536e-05
# Epoch 30 Iteration 14
# Loss: 1.7050588e-05
# Epoch 30 Iteration 15
# Loss: 1.1965213e-05
# Epoch 30 Iteration 16
# Loss: 3.4494682e-05
# Epoch 30 Iteration 17
# Loss: 3.2335658e-05
# Epoch 30 Iteration 18
# Loss: 3.9525643e-05
# Epoch 30 Iteration 19
# Loss: 1.2115318e-05
# Epoch 30 Iteration 20
# Loss: 3.5016266e-05
# Epoch 30 Iteration 21
# Loss: 3.2026615e-05
# Epoch 30 Iteration 22
# Loss: 7.965067e-06
# Epoch 30 Iteration 23
# Loss: 1.3304347e-05
# Epoch 30 Iteration 24
# Loss: 7.3621404e-06
# Epoch 30 Iteration 25
# Loss: 1.5581823e-05
# Epoch 30 Iteration 26
# Loss: 2.6429829e-05
# Epoch 30 Iteration 27
# Loss: 0.00010223584
# Epoch 30 Iteration 28
# Loss: 2.3986033e-05
# Epoch 30 Iteration 29
# Loss: 5.644603e-05
# Epoch 30 Iteration 30
# Loss: 4.037766e-06
# Epoch 30 Iteration 31
# Loss: 2.8897426e-05
# Epoch 30 Iteration 32
# Loss: 5.175463e-05
# Epoch 30 Iteration 33
# Loss: 4.2320382e-05
# Epoch 30 Iteration 34
# Loss: 2.1984686e-05
# Valid loss: 1.7541697161505e-05
# Epoch  31  Current time:  Mon Jun 22 02:59:35 2020
# Epoch 31 Iteration 0
# Loss: 4.7335216e-05
# Epoch 31 Iteration 1
# Loss: 1.0037048e-05
# Epoch 31 Iteration 2
# Loss: 4.4532877e-05
# Epoch 31 Iteration 3
# Loss: 3.634476e-05
# Epoch 31 Iteration 4
# Loss: 3.102531e-05
# Epoch 31 Iteration 5
# Loss: 1.8358858e-05
# Epoch 31 Iteration 6
# Loss: 8.029944e-06
# Epoch 31 Iteration 7
# Loss: 4.499103e-06
# Epoch 31 Iteration 8
# Loss: 3.528283e-05
# Epoch 31 Iteration 9
# Loss: 3.0331345e-05
# Epoch 31 Iteration 10
# Loss: 1.2894917e-05
# Epoch 31 Iteration 11
# Loss: 3.215082e-05
# Epoch 31 Iteration 12
# Loss: 6.256179e-05
# Epoch 31 Iteration 13
# Loss: 8.797058e-05
# Epoch 31 Iteration 14
# Loss: 2.2262899e-05
# Epoch 31 Iteration 15
# Loss: 3.7926857e-06
# Epoch 31 Iteration 16
# Loss: 2.0011474e-05
# Epoch 31 Iteration 17
# Loss: 2.4804782e-05
# Epoch 31 Iteration 18
# ...
# Epoch 39 Iteration 20
# Loss: 2.7364456e-05
# Epoch 39 Iteration 21
# Loss: 1.49153575e-05
# Epoch 39 Iteration 22
# Loss: 1.9224382e-05
# Epoch 39 Iteration 23
# Loss: 2.5482459e-05
# Epoch 39 Iteration 24
# Loss: 4.223333e-06
# Epoch 39 Iteration 25
# Loss: 3.7074008e-06
# Epoch 39 Iteration 26
# Loss: 6.454913e-06
# Epoch 39 Iteration 27
# Loss: 4.2533677e-05
# Epoch 39 Iteration 28
# Loss: 3.7797956e-05
# Epoch 39 Iteration 29
# Loss: 3.427494e-05
# Epoch 39 Iteration 30
# Loss: 1.2851496e-05
# Epoch 39 Iteration 31
# Loss: 3.0141742e-05
# Epoch 39 Iteration 32
# Loss: 4.761695e-05
# Epoch 39 Iteration 33
# Loss: 5.954773e-05
# Epoch 39 Iteration 34
# Loss: 1.780124e-05
# Valid loss: 1.617330599401612e-05
# Epoch  40  Current time:  Mon Jun 22 03:06:36 2020
# Epoch 40 Iteration 0
# Loss: 2.3506742e-05
# Epoch 40 Iteration 1
# Loss: 2.5581992e-05
# Epoch 40 Iteration 2
# Loss: 7.56611e-06
# Epoch 40 Iteration 3
# Loss: 7.3222127e-06
# Epoch 40 Iteration 4
# Loss: 1.0697073e-05
# Epoch 40 Iteration 5
# Loss: 4.9290584e-06
# Epoch 40 Iteration 6
# Loss: 4.3660704e-05
# Epoch 40 Iteration 7
# Loss: 4.288817e-06
# Epoch 40 Iteration 8
# Loss: 9.176287e-05
# Epoch 40 Iteration 9
# Loss: 1.3077363e-05
# Epoch 40 Iteration 10
# Loss: 4.4201617e-05
# Epoch 40 Iteration 11
# Loss: 6.604007e-06
# Epoch 40 Iteration 12
# Loss: 2.2367236e-05
# Epoch 40 Iteration 13
# Loss: 5.5648114e-05
# Epoch 40 Iteration 14
# Loss: 1.190278e-05
# Epoch 40 Iteration 15
# Loss: 1.519304e-05
# Epoch 40 Iteration 16
# Loss: 2.965505e-05
# Epoch 40 Iteration 17
# Loss: 1.1080457e-05
# Epoch 40 Iteration 18
# Loss: 5.15657e-05
# Epoch 40 Iteration 19
# Loss: 3.645885e-05
# Epoch 40 Iteration 20
# Loss: 1.9572655e-05
# Epoch 40 Iteration 21
# Loss: 1.9647792e-05
# Epoch 40 Iteration 22
# Loss: 3.319873e-05
# Epoch 40 Iteration 23
# Loss: 1.3219235e-05
# Epoch 40 Iteration 24
# Loss: 3.145254e-05
# Epoch 40 Iteration 25
# Loss: 4.2788874e-05
# Epoch 40 Iteration 26
# Loss: 2.8077586e-05
# Epoch 40 Iteration 27
# Loss: 5.8780595e-05
# Epoch 40 Iteration 28
# Loss: 1.6786886e-05
# Epoch 40 Iteration 29
# Loss: 4.281444e-05
# Epoch 40 Iteration 30
# Loss: 3.8930784e-06
# Epoch 40 Iteration 31
# Loss: 1.1259798e-05
# Epoch 40 Iteration 32
# Loss: 2.3250663e-05
# Epoch 40 Iteration 33
# Loss: 3.522314e-05
# Epoch 40 Iteration 34
# Loss: 4.2050742e-05
# Valid loss: 1.5021794752101414e-05
# Epoch  41  Current time:  Mon Jun 22 03:07:23 2020
# Epoch 41 Iteration 0
# Loss: 5.670581e-05
# Epoch 41 Iteration 1
# Loss: 3.6958234e-05
# Epoch 41 Iteration 2
# Loss: 1.8950248e-05
# Epoch 41 Iteration 3
# Loss: 9.729819e-06
# Epoch 41 Iteration 4
# Loss: 3.2581433e-05
# Epoch 41 Iteration 5
# Loss: 2.2366174e-05
# Epoch 41 Iteration 6
# Loss: 5.0653205e-05
# Epoch 41 Iteration 7
# Loss: 4.0581626e-06
# Epoch 41 Iteration 8
# Loss: 2.8005557e-05
# Epoch 41 Iteration 9
# Loss: 1.2409199e-05
# Epoch 41 Iteration 10
# Loss: 6.6961875e-06
# Epoch 41 Iteration 11
# Loss: 4.446292e-05
# Epoch 41 Iteration 12
# Loss: 1.2666782e-05
# Epoch 41 Iteration 13
# Loss: 6.714904e-06
# Epoch 41 Iteration 14
# Loss: 3.6921672e-05
# Epoch 41 Iteration 15
# Loss: 1.9763831e-05
# Epoch 41 Iteration 16
# Loss: 2.4841585e-05
# Epoch 41 Iteration 17
# Loss: 4.6570935e-06
# Epoch 41 Iteration 18
# Loss: 2.772536e-05
# Epoch 41 Iteration 19
# Loss: 1.1808825e-05
# Epoch 41 Iteration 20
# Loss: 2.9665043e-05
# Epoch 41 Iteration 21
# Loss: 2.358768e-05
# Epoch 41 Iteration 22
# Loss: 1.115216e-05
# Epoch 41 Iteration 23
# Loss: 3.628219e-05
# Epoch 41 Iteration 24
# Loss: 3.0143652e-05
# Epoch 41 Iteration 25
# Loss: 3.688255e-06
# Epoch 41 Iteration 26
# Loss: 1.1640483e-05
# Epoch 41 Iteration 27
# Loss: 4.092023e-05
# Epoch 41 Iteration 28
# Loss: 3.2220476e-05
# Epoch 41 Iteration 29
# Loss: 8.927543e-05
# Epoch 41 Iteration 30
# Loss: 1.7668572e-05
# Epoch 41 Iteration 31
# Loss: 6.9058615e-06
# Epoch 41 Iteration 32
# Loss: 4.5228e-05
# Epoch 41 Iteration 33
# Loss: 1.6098804e-05
# Epoch 41 Iteration 34
# Loss: 4.596436e-05
# Valid loss: 1.4919371096766554e-05
# Epoch  42  Current time:  Mon Jun 22 03:08:09 2020
# Epoch 42 Iteration 0
# Loss: 8.331999e-05
# Epoch 42 Iteration 1
# Loss: 2.7010861e-05
# Epoch 42 Iteration 2
# Loss: 1.5144314e-05
# Epoch 42 Iteration 3
# Loss: 2.1717957e-05
# Epoch 42 Iteration 4
# Loss: 2.0808884e-05
# Epoch 42 Iteration 5
# Loss: 3.4717374e-05
# Epoch 42 Iteration 6
# Loss: 1.098927e-05
# Epoch 42 Iteration 7
# Loss: 3.7011769e-06
# Epoch 42 Iteration 8
# Loss: 6.866133e-06
# Epoch 42 Iteration 9
# Loss: 4.76627e-05
# Epoch 42 Iteration 10
# Loss: 6.466579e-06
# Epoch 42 Iteration 11
# Loss: 1.0149637e-05
# Epoch 42 Iteration 12
# Loss: 5.200403e-05
# Epoch 42 Iteration 13
# Loss: 3.427969e-05
# Epoch 42 Iteration 14
# Loss: 2.6085727e-05
# Epoch 42 Iteration 15
# Loss: 1.6999844e-05
# Epoch 42 Iteration 16
# Loss: 3.510523e-05
# Epoch 42 Iteration 17
# Loss: 4.5030374e-05
# Epoch 42 Iteration 18
# Loss: 3.1749267e-05
# Epoch 42 Iteration 19
# Loss: 3.6969035e-05
# Epoch 42 Iteration 20
# Loss: 7.4996688e-06
# Epoch 42 Iteration 21
# Loss: 5.389104e-05
# Epoch 42 Iteration 22
# Loss: 3.3158136e-05
# Epoch 42 Iteration 23
# Loss: 3.518304e-05
# Epoch 42 Iteration 24
# Loss: 2.2532242e-05
# Epoch 42 Iteration 25
# Loss: 6.14464e-05
# Epoch 42 Iteration 26
# Loss: 1.1846152e-05
# Epoch 42 Iteration 27
# Loss: 2.0122678e-05
# Epoch 42 Iteration 28
# Loss: 2.3238692e-05
# Epoch 42 Iteration 29
# Loss: 4.6537725e-06
# Epoch 42 Iteration 30
# Loss: 1.6584183e-05
# Epoch 42 Iteration 31
# Loss: 1.950377e-05
# Epoch 42 Iteration 32
# Loss: 3.4134364e-06
# Epoch 42 Iteration 33
# Loss: 4.0348434e-05
# Epoch 42 Iteration 34
# Loss: 1.1629005e-05
# Valid loss: 1.5358233213191852e-05
# Epoch  43  Current time:  Mon Jun 22 03:08:56 2020
# Epoch 43 Iteration 0
# Loss: 1.6620383e-05
# Epoch 43 Iteration 1
# Loss: 5.8905853e-06
# Epoch 43 Iteration 2
# Loss: 3.0284506e-05
# Epoch 43 Iteration 3
# Loss: 1.8422807e-05
# Epoch 43 Iteration 4
# Loss: 4.009198e-05
# Epoch 43 Iteration 5
# Loss: 4.4310636e-05
# Epoch 43 Iteration 6
# Loss: 6.6048997e-06
# Epoch 43 Iteration 7
# Loss: 4.390273e-05
# Epoch 43 Iteration 8
# Loss: 3.39171e-05
# Epoch 43 Iteration 9
# Loss: 1.1503271e-05
# Epoch 43 Iteration 10
# Loss: 1.1341821e-05
# Epoch 43 Iteration 11
# Loss: 2.129812e-05
# Epoch 43 Iteration 12
# Loss: 1.6452665e-05
# Epoch 43 Iteration 13
# Loss: 2.9037794e-05
# Epoch 43 Iteration 14
# Loss: 1.4275494e-05
# Epoch 43 Iteration 15
# Loss: 1.2636832e-05
# Epoch 43 Iteration 16
# Loss: 3.555666e-05
# Epoch 43 Iteration 17
# Loss: 1.13044935e-05
# Epoch 43 Iteration 18
# Loss: 2.839746e-05
# Epoch 43 Iteration 19
# Loss: 3.191136e-06
# Epoch 43 Iteration 20
# Loss: 3.7549278e-06
# Epoch 43 Iteration 21
# Loss: 2.4935283e-05
# Epoch 43 Iteration 22
# Loss: 9.614661e-06
# Epoch 43 Iteration 23
# Loss: 2.321943e-05
# Epoch 43 Iteration 24
# Loss: 5.5797424e-05
# Epoch 43 Iteration 25
# Loss: 6.766817e-06
# Epoch 43 Iteration 26
# Loss: 3.58031e-05
# Epoch 43 Iteration 27
# Loss: 8.511249e-05
# Epoch 43 Iteration 28
# Loss: 4.3723066e-05
# Epoch 43 Iteration 29
# Loss: 4.914493e-06
# Epoch 43 Iteration 30
# Loss: 4.2570387e-05
# Epoch 43 Iteration 31
# Loss: 4.1650957e-05
# Epoch 43 Iteration 32
# Loss: 5.0764113e-05
# Epoch 43 Iteration 33
# Loss: 2.856608e-05
# Epoch 43 Iteration 34
# Loss: 1.97253e-05
# Valid loss: 1.650221565796528e-05
# Epoch  44  Current time:  Mon Jun 22 03:09:43 2020
# Epoch 44 Iteration 0
# Loss: 4.2656975e-05
# Epoch 44 Iteration 1
# Loss: 3.0444644e-05
# Epoch 44 Iteration 2
# Loss: 1.3353109e-05
# Epoch 44 Iteration 3
# Loss: 1.5655309e-05
# Epoch 44 Iteration 4
# Loss: 4.00344e-05
# Epoch 44 Iteration 5
# Loss: 2.3478775e-05
# Epoch 44 Iteration 6
# Loss: 5.8069136e-06
# Epoch 44 Iteration 7
# Loss: 3.1526077e-05
# Epoch 44 Iteration 8
# Loss: 4.6154833e-05
# Epoch 44 Iteration 9
# Loss: 4.4185257e-05
# Epoch 44 Iteration 10
# Loss: 2.2668912e-05
# Epoch 44 Iteration 11
# Loss: 2.7611046e-05
# Epoch 44 Iteration 12
# Loss: 5.998232e-05
# Epoch 44 Iteration 13
# Loss: 4.54491e-05
# Epoch 44 Iteration 14
# Loss: 1.347437e-05
# Epoch 44 Iteration 15
# Loss: 1.36005665e-05
# Epoch 44 Iteration 16
# Loss: 3.677849e-05
# Epoch 44 Iteration 17
# Loss: 7.3310684e-06
# Epoch 44 Iteration 18
# Loss: 1.7163173e-05
# Epoch 44 Iteration 19
# Loss: 3.1078904e-05
# Epoch 44 Iteration 20
# Loss: 1.2153343e-05
# Epoch 44 Iteration 21
# Loss: 5.2786898e-05
# Epoch 44 Iteration 22
# Loss: 6.5832064e-06
# Epoch 44 Iteration 23
# Loss: 4.0366735e-06
# Epoch 44 Iteration 24
# Loss: 9.090126e-05
# Epoch 44 Iteration 25
# Loss: 3.352138e-05
# Epoch 44 Iteration 26
# Loss: 2.4969979e-05
# Epoch 44 Iteration 27
# Loss: 1.1413691e-05
# Epoch 44 Iteration 28
# Loss: 3.1704323e-05
# Epoch 44 Iteration 29
# Loss: 2.2083314e-05
# Epoch 44 Iteration 30
# Loss: 4.1918915e-06
# Epoch 44 Iteration 31
# Loss: 4.5642023e-06
# Epoch 44 Iteration 32
# Loss: 5.657872e-05
# Epoch 44 Iteration 33
# Loss: 1.2187161e-05
# Epoch 44 Iteration 34
# Loss: 3.1095733e-05
# Valid loss: 1.5086751773196738e-05
# Epoch  45  Current time:  Mon Jun 22 03:10:30 2020
# Epoch 45 Iteration 0
# Loss: 5.984256e-06
# Epoch 45 Iteration 1
# Loss: 2.117748e-05
# Epoch 45 Iteration 2
# Loss: 4.6926025e-06
# Epoch 45 Iteration 3
# Loss: 4.208636e-05
# Epoch 45 Iteration 4
# Loss: 5.274495e-05
# Epoch 45 Iteration 5
# Loss: 3.245846e-05
# Epoch 45 Iteration 6
# Loss: 1.1608239e-05
# Epoch 45 Iteration 7
# Loss: 4.924487e-06
# Epoch 45 Iteration 8
# Loss: 1.1764614e-05
# Epoch 45 Iteration 9
# Loss: 4.0233394e-05
# Epoch 45 Iteration 10
# Loss: 5.138863e-05
# Epoch 45 Iteration 11
# Loss: 2.9201829e-05
# Epoch 45 Iteration 12
# Loss: 2.8739783e-05
# Epoch 45 Iteration 13
# Loss: 1.6130887e-05
# Epoch 45 Iteration 14
# Loss: 7.705577e-06
# Epoch 45 Iteration 15
# Loss: 4.9866838e-05
# Epoch 45 Iteration 16
# Loss: 4.4456192e-05
# Epoch 45 Iteration 17
# Loss: 2.5375168e-05
# Epoch 45 Iteration 18
# Loss: 6.20024e-05
# Epoch 45 Iteration 19
# Loss: 1.8644208e-05
# Epoch 45 Iteration 20
# Loss: 2.5537824e-05
# Epoch 45 Iteration 21
# Loss: 3.367223e-05
# Epoch 45 Iteration 22
# Loss: 2.3615634e-05
# Epoch 45 Iteration 23
# Loss: 1.42953995e-05
# Epoch 45 Iteration 24
# Loss: 1.2829849e-05
# Epoch 45 Iteration 25
# Loss: 1.14059985e-05
# Epoch 45 Iteration 26
# Loss: 1.7991946e-05
# Epoch 45 Iteration 27
# Loss: 3.88996e-05
# Epoch 45 Iteration 28
# Loss: 1.0594719e-05
# Epoch 45 Iteration 29
# Loss: 2.7287157e-05
# Epoch 45 Iteration 30
# Loss: 6.3961793e-06
# Epoch 45 Iteration 31
# Loss: 3.2489646e-05
# Epoch 45 Iteration 32
# Loss: 8.149617e-05
# Epoch 45 Iteration 33
# Loss: 2.0483192e-05
# Epoch 45 Iteration 34
# Loss: 5.277389e-05
# Valid loss: 1.558808253321331e-05
# Epoch  46  Current time:  Mon Jun 22 03:11:16 2020
# Epoch 46 Iteration 0
# Loss: 3.1007494e-05
# Epoch 46 Iteration 1
# Loss: 1.1574146e-05
# Epoch 46 Iteration 2
# Loss: 1.2829018e-05
# Epoch 46 Iteration 3
# Loss: 5.307925e-05
# Epoch 46 Iteration 4
# Loss: 4.1087364e-06
# Epoch 46 Iteration 5
# Loss: 1.9704357e-05
# Epoch 46 Iteration 6
# Loss: 4.3702792e-05
# Epoch 46 Iteration 7
# Loss: 1.687295e-05
# Epoch 46 Iteration 8
# Loss: 3.7177593e-05
# Epoch 46 Iteration 9
# Loss: 2.6658057e-05
# Epoch 46 Iteration 10
# Loss: 1.3564718e-05
# Epoch 46 Iteration 11
# Loss: 4.7145582e-05
# Epoch 46 Iteration 12
# Loss: 3.772034e-05
# Epoch 46 Iteration 13
# Loss: 5.241876e-06
# Epoch 46 Iteration 14
# Loss: 1.1872039e-05
# Epoch 46 Iteration 15
# Loss: 4.1605876e-05
# Epoch 46 Iteration 16
# Loss: 7.406734e-06
# Epoch 46 Iteration 17
# Loss: 3.719682e-05
# Epoch 46 Iteration 18
# Loss: 1.5401105e-05
# Epoch 46 Iteration 19
# Loss: 3.0224317e-05
# Epoch 46 Iteration 20
# Loss: 2.2570635e-05
# Epoch 46 Iteration 21
# Loss: 2.8769775e-05
# Epoch 46 Iteration 22
# Loss: 4.604187e-06
# Epoch 46 Iteration 23
# Loss: 3.2650027e-05
# Epoch 46 Iteration 24
# Loss: 2.2275439e-05
# Epoch 46 Iteration 25
# Loss: 4.5993133e-05
# Epoch 46 Iteration 26
# Loss: 2.6759775e-05
# Epoch 46 Iteration 27
# Loss: 9.921305e-06
# Epoch 46 Iteration 28
# Loss: 6.117216e-05
# Epoch 46 Iteration 29
# Loss: 1.0792774e-05
# Epoch 46 Iteration 30
# Loss: 1.902617e-05
# Epoch 46 Iteration 31
# Loss: 2.6155049e-05
# Epoch 46 Iteration 32
# Loss: 5.7569905e-06
# Epoch 46 Iteration 33
# Loss: 6.394754e-06
# Epoch 46 Iteration 34
# Loss: 0.000105343
# Valid loss: 1.6484575098729692e-05
# Epoch  47  Current time:  Mon Jun 22 03:12:03 2020
# Epoch 47 Iteration 0
# Loss: 6.938427e-06
# Epoch 47 Iteration 1
# Loss: 2.806928e-06
# Epoch 47 Iteration 2
# Loss: 2.2244218e-05
# Epoch 47 Iteration 3
# Loss: 2.6229463e-05
# Epoch 47 Iteration 4
# Loss: 3.7378393e-06
# Epoch 47 Iteration 5
# Loss: 1.0529551e-05
# Epoch 47 Iteration 6
# Loss: 3.1096075e-05
# Epoch 47 Iteration 7
# Loss: 3.7050624e-05
# Epoch 47 Iteration 8
# Loss: 3.0974334e-05
# Epoch 47 Iteration 9
# Loss: 3.9157567e-05
# Epoch 47 Iteration 10
# Loss: 2.124348e-05
# Epoch 47 Iteration 11
# Loss: 4.492502e-05
# Epoch 47 Iteration 12
# Loss: 2.5847197e-05
# Epoch 47 Iteration 13
# Loss: 2.4145751e-05
# Epoch 47 Iteration 14
# Loss: 2.8856011e-05
# Epoch 47 Iteration 15
# Loss: 0.00010005733
# Epoch 47 Iteration 16
# Loss: 1.1326574e-05
# Epoch 47 Iteration 17
# Loss: 1.3967101e-05
# Epoch 47 Iteration 18
# Loss: 4.5685792e-06
# Epoch 47 Iteration 19
# Loss: 1.7164277e-05
# Epoch 47 Iteration 20
# Loss: 5.1160216e-05
# Epoch 47 Iteration 21
# Loss: 1.2320266e-05
# Epoch 47 Iteration 22
# Loss: 1.8435052e-05
# Epoch 47 Iteration 23
# Loss: 2.949563e-05
# Epoch 47 Iteration 24
# Loss: 4.6318215e-05
# Epoch 47 Iteration 25
# Loss: 3.4762572e-05
# Epoch 47 Iteration 26
# Loss: 6.0860075e-05
# Epoch 47 Iteration 27
# Loss: 6.5969384e-06
# Epoch 47 Iteration 28
# Loss: 9.6465365e-06
# Epoch 47 Iteration 29
# Loss: 4.4936653e-05
# Epoch 47 Iteration 30
# Loss: 1.1549973e-05
# Epoch 47 Iteration 31
# Loss: 5.3214753e-05
# Epoch 47 Iteration 32
# Loss: 2.9973147e-05
# Epoch 47 Iteration 33
# Loss: 3.2140062e-05
# Epoch 47 Iteration 34
# Loss: 1.1942488e-05
# Valid loss: 1.5559624443994835e-05
# Epoch  48  Current time:  Mon Jun 22 03:12:50 2020
# Epoch 48 Iteration 0
# Loss: 3.1580064e-05
# Epoch 48 Iteration 1
# Loss: 1.9501727e-05
# Epoch 48 Iteration 2
# Loss: 3.98481e-05
# Epoch 48 Iteration 3
# Loss: 5.5070013e-05
# Epoch 48 Iteration 4
# Loss: 3.6410713e-06
# Epoch 48 Iteration 5
# Loss: 1.2787569e-05
# Epoch 48 Iteration 6
# Loss: 6.428934e-06
# Epoch 48 Iteration 7
# Loss: 5.0702078e-05
# Epoch 48 Iteration 8
# Loss: 2.8135084e-05
# Epoch 48 Iteration 9
# Loss: 4.2970732e-05
# Epoch 48 Iteration 10
# Loss: 1.2833631e-05
# Epoch 48 Iteration 11
# Loss: 7.753552e-05
# Epoch 48 Iteration 12
# Loss: 1.0626818e-05
# Epoch 48 Iteration 13
# Loss: 2.1770888e-05
# Epoch 48 Iteration 14
# Loss: 3.720483e-05
# Epoch 48 Iteration 15
# Loss: 7.926675e-06
# Epoch 48 Iteration 16
# Loss: 1.267039e-05
# Epoch 48 Iteration 17
# Loss: 2.7044987e-05
# Epoch 48 Iteration 18
# Loss: 1.0305323e-05
# Epoch 48 Iteration 19
# Loss: 3.5075773e-05
# Epoch 48 Iteration 20
# Loss: 3.193835e-05
# Epoch 48 Iteration 21
# Loss: 1.0159494e-05
# Epoch 48 Iteration 22
# Loss: 4.19331e-05
# Epoch 48 Iteration 23
# Loss: 2.525042e-05
# Epoch 48 Iteration 24
# Loss: 2.1752527e-05
# Epoch 48 Iteration 25
# Loss: 1.9280693e-05
# Epoch 48 Iteration 26
# Loss: 2.6462716e-05
# Epoch 48 Iteration 27
# Loss: 1.9883413e-05
# Epoch 48 Iteration 28
# Loss: 4.40597e-06
# Epoch 48 Iteration 29
# Loss: 4.3283468e-05
# Epoch 48 Iteration 30
# Loss: 1.6683556e-05
# Epoch 48 Iteration 31
# Loss: 1.31294555e-05
# Epoch 48 Iteration 32
# Loss: 4.7598814e-06
# Epoch 48 Iteration 33
# Loss: 3.4090353e-05
# Epoch 48 Iteration 34
# Loss: 1.591572e-05
# Valid loss: 1.4897239452693611e-05
# Epoch  49  Current time:  Mon Jun 22 03:13:37 2020
# Epoch 49 Iteration 0
# Loss: 1.028505e-05
# Epoch 49 Iteration 1
# Loss: 2.202904e-05
# Epoch 49 Iteration 2
# Loss: 3.7607533e-05
# Epoch 49 Iteration 3
# Loss: 3.4045013e-05
# Epoch 49 Iteration 4
# Loss: 1.0422244e-05
# Epoch 49 Iteration 5
# Loss: 4.6233567e-05
# Epoch 49 Iteration 6
# Loss: 1.8538238e-05
# Epoch 49 Iteration 7
# Loss: 2.4268702e-06
# Epoch 49 Iteration 8
# Loss: 4.39456e-05
# Epoch 49 Iteration 9
# Loss: 3.2117056e-05
# Epoch 49 Iteration 10
# Loss: 2.0117322e-05
# Epoch 49 Iteration 11
# Loss: 2.6051246e-05
# Epoch 49 Iteration 12
# Loss: 2.4068342e-05
# Epoch 49 Iteration 13
# Loss: 4.5529356e-05
# Epoch 49 Iteration 14
# Loss: 7.5137825e-05
# Epoch 49 Iteration 15
# Loss: 1.9510255e-05
# Epoch 49 Iteration 16
# Loss: 2.5634981e-05
# Epoch 49 Iteration 17
# Loss: 4.7174162e-05
# Epoch 49 Iteration 18
# Loss: 4.251662e-06
# Epoch 49 Iteration 19
# Loss: 2.8093831e-05
# Epoch 49 Iteration 20
# Loss: 1.2166352e-05
# Epoch 49 Iteration 21
# Loss: 5.5762495e-05
# Epoch 49 Iteration 22
# Loss: 1.6973248e-05
# Epoch 49 Iteration 23
# Loss: 1.1932169e-05
# Epoch 49 Iteration 24
# Loss: 4.228687e-05
# Epoch 49 Iteration 25
# Loss: 3.82608e-05
# Epoch 49 Iteration 26
# Loss: 2.1993603e-05
# Epoch 49 Iteration 27
# Loss: 5.7119028e-06
# Epoch 49 Iteration 28
# Loss: 1.1378712e-05
# Epoch 49 Iteration 29
# Loss: 1.4798046e-05
# Epoch 49 Iteration 30
# Loss: 2.959847e-05
# Epoch 49 Iteration 31
# Loss: 6.0899424e-06
# Epoch 49 Iteration 32
# Loss: 4.780385e-06
# Epoch 49 Iteration 33
# Loss: 9.604473e-06
# Epoch 49 Iteration 34
# Loss: 6.633479e-06
# Valid loss: 1.4693626326334197e-05

# %%
if isTrain:
    ti = time.time()-nowtime
    print("Training time: %d min, %d sec"% (ti/60, ti%60))
# Out:
# Training time: 38 min, 53 sec

# %%
vv_list = np.multiply(np.asarray(valid_loss_in_epoch),2.5)

# %%
print(np.asarray(valid_loss_in_epoch).shape)
if isTrain:
    x = np.linspace(0,50,50)
    x1 = np.linspace(0,50,50)
    plt.plot(x, loss_list, label='loss')
    plt.plot(x1, vv_list, label='valid loss')
    plt.legend(loc='upper right')
    plt.ticklabel_format(useOffset=False)
    plt.show()
# Out:
# (50,)

# %%
'''
shuff = [34,  0, 11, 21, 12, 27,  5,  2, 38, 25,  7, 15,  4, 39, 31,  8, 22,  6, 28, 26, 24, 19,  3, 23,
  1, 17, 20, 18, 33, 10, 14, 35, 29, 30, 16, 36,  9, 37, 32, 13]

test_nii_CT = np.concatenate((flair_nii_CT[:20], t1ce_nii_CT[:20]),axis=0)
test_nii_label = np.concatenate((nii_label[:20], nii_label[:20]), axis=0)
print(test_nii_CT.shape)
print(test_nii_label.shape)

test_nii_CT = test_nii_CT[shuff]
test_nii_label = test_nii_label[shuff]

n1 = []
n2 = []
for i in range(test_nii_CT.shape[0]):
    image1 = scale_3d(test_nii_CT[i])
    image2 = scale_3d(test_nii_label[i])
    n1.append(image1)
    n2.append(image2)
    
test_dataset = np.asarray(n1[:35])
test_label = np.asarray(n2[:35])

onehot_array = []

for i in range(test_label.shape[0]):
    onehot_nii_label = value2onehot(test_label[i])
    onehot_array.append(onehot_nii_label)

ground_truth = np.asarray(onehot_array, dtype=np.uint8)
'''

test_dataset = data_3d
ground_truth = label_3d
#test_dataset = np.load('./test_nii_data.npy')
#ground_truth = np.load('./test_nii_label.npy')
print(test_dataset.shape)
print(ground_truth.shape)
# Out:
# (35, 128, 128, 128)
# (35, 128, 128, 128, 4)

# %%
nowtime = time.time()

with tf.Session() as session:
    if isTrain:
        saver.restore(session, "./"+checkpoint_dir+"/"+"Unet_epoch_"+str(49-1)+".ckpt")
    else:
        saver.restore(session, "./"+checkpoint_dir+"/"+"Unet_epoch_"+str(26)+".ckpt")
    print("Model restored.") 
    print('Initialized')

    for i in range(test_dataset.shape[0]):
        print("Testing batch ", i)
        test_image = test_dataset[i]
        feed_dict=dict()
        feed_dict.update({placeholders['input']:test_image.reshape(batch_size,input_depth,input_height,input_width,1)})

        gen = session.run(tf.nn.softmax(Unet_out_tensor),feed_dict=feed_dict)
    
        #print(np.unique(gen), np.unique(gen))
        gen = gen.reshape([input_depth,input_height,input_width,output_class_num])
        #print(gen[0][0])
        value_gen = onehot2value(gen)
        value_gen = value_gen.reshape([batch_size, input_depth,input_height,input_width])
        if i == 0 :
            test_output = value_gen
        else:
            test_output = np.concatenate((test_output,value_gen), axis = 0)
        
    
#         test_output = np.asarray(test_output)
        print("test_output size", test_output.shape)

ti = time.time()-nowtime
print("Testing time: %d min, %d sec"% (ti/60, ti%60))
# Out:
# INFO:tensorflow:Restoring parameters from ./checkpoint_flair/Unet_epoch_48.ckpt
# Model restored.
# Initialized
# Testing batch  0
# test_output size (1, 128, 128, 128)
# Testing batch  1
# test_output size (2, 128, 128, 128)
# Testing batch  2
# test_output size (3, 128, 128, 128)
# Testing batch  3
# test_output size (4, 128, 128, 128)
# Testing batch  4
# test_output size (5, 128, 128, 128)
# Testing batch  5
# test_output size (6, 128, 128, 128)
# Testing batch  6
# test_output size (7, 128, 128, 128)
# Testing batch  7
# test_output size (8, 128, 128, 128)
# Testing batch  8
# test_output size (9, 128, 128, 128)
# Testing batch  9
# test_output size (10, 128, 128, 128)
# Testing batch  10
# test_output size (11, 128, 128, 128)
# Testing batch  11
# test_output size (12, 128, 128, 128)
# Testing batch  12
# test_output size (13, 128, 128, 128)
# Testing batch  13
# test_output size (14, 128, 128, 128)
# Testing batch  14
# test_output size (15, 128, 128, 128)
# Testing batch  15
# test_output size (16, 128, 128, 128)
# Testing batch  16
# test_output size (17, 128, 128, 128)
# Testing batch  17
# test_output size (18, 128, 128, 128)
# Testing batch  18
# test_output size (19, 128, 128, 128)
# Testing batch  19
# test_output size (20, 128, 128, 128)
# Testing batch  20
# test_output size (21, 128, 128, 128)
# Testing batch  21
# test_output size (22, 128, 128, 128)
# Testing batch  22
# test_output size (23, 128, 128, 128)
# Testing batch  23
# test_output size (24, 128, 128, 128)
# Testing batch  24
# test_output size (25, 128, 128, 128)
# Testing batch  25
# test_output size (26, 128, 128, 128)
# Testing batch  26
# test_output size (27, 128, 128, 128)
# Testing batch  27
# test_output size (28, 128, 128, 128)
# Testing batch  28
# test_output size (29, 128, 128, 128)
# Testing batch  29
# test_output size (30, 128, 128, 128)
# Testing batch  30
# test_output size (31, 128, 128, 128)
# Testing batch  31
# test_output size (32, 128, 128, 128)
# Testing batch  32
# test_output size (33, 128, 128, 128)
# Testing batch  33
# test_output size (34, 128, 128, 128)
# Testing batch  34
# test_output size (35, 128, 128, 128)
# Testing time: 1 min, 46 sec

# %%
np.save('testing_result_only_flair2', test_output)

# %%
'''
print('Whole volume f1 score')
seg = output_onehot
gt = ground_truth_onehot
evaluation(gt, seg)
'''

output_onehot = []
for i in range(test_output.shape[0]):
    onehot_array = value2onehot(test_output[i])
    output_onehot.append(onehot_array)
output_onehot = np.asarray(output_onehot, dtype=np.uint8)
ground_truth_onehot = ground_truth

# %%
for idx in range(output_onehot.shape[0]):
    dice = []
    hausdorff = []
    for sl in range(output_onehot.shape[1]):
        seg = output_onehot[idx][sl]
        gt = ground_truth_onehot[idx][sl]
        d, h = evaluation_return(gt,seg)
        dice.append(d)
        hausdorff.append(h)

    dice = np.asarray(dice)
    print('patient idx: ', idx)
    print('dice shape: ',dice.shape)
    hausdorff = np.asarray(hausdorff)
    print('hausdorff shape: ', hausdorff.shape)
    print("Dice mean:", np.mean(dice), "STD:",np.std(dice))
    print("Hausdorff mean:", np.mean(hausdorff), "STD:",np.std(hausdorff))
    print("--------------------------------\n")
    with open('testing_output_only_flair2.csv', 'a', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow([idx, np.mean(dice), np.std(dice), np.mean(hausdorff), np.std(hausdorff)])
# Out:
# patient idx:  0
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.625 STD: 0.44876373392787533
# Hausdorff mean: 1.2233621623190711 STD: 1.5253213903739167
# --------------------------------
#
# patient idx:  1
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.7258494876944354 STD: 0.35693874302376777
# Hausdorff mean: 0.8699890032715591 STD: 1.132990119366717
# --------------------------------
#
# patient idx:  2
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.6252508399124379 STD: 0.4216276511410515
# Hausdorff mean: 1.060140125517644 STD: 1.27205443064456
# --------------------------------
#
# patient idx:  3
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.8177083333333334 STD: 0.3141881485803265
# Hausdorff mean: 0.5449030419671208 STD: 0.8783845062140663
# --------------------------------
#
# patient idx:  4
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.8854166666666667 STD: 0.2714336295999038
# Hausdorff mean: 0.2879575780421117 STD: 0.6850697809485278
# --------------------------------
#
# patient idx:  5
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.6432291666666667 STD: 0.4333805938771435
# Hausdorff mean: 1.0690700391390708 STD: 1.3670610738703348
# --------------------------------
#
# patient idx:  6
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.8177083333333334 STD: 0.3250517453464568
# Hausdorff mean: 0.5075835389021164 STD: 0.9328699997140553
# --------------------------------
#
# patient idx:  7
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.59375 STD: 0.46386341829608996
# Hausdorff mean: 1.0662137380678582 STD: 1.2916667434544578
# --------------------------------
#
# patient idx:  8
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.6765631486512156 STD: 0.4141691900668986
# Hausdorff mean: 1.1708885102563062 STD: 1.5654412841729584
# --------------------------------
#
# patient idx:  9
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.59375 STD: 0.4694439308018229
# Hausdorff mean: 1.309178122864243 STD: 1.5933175658773955
# --------------------------------
#
# patient idx:  10
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.5816013427349124 STD: 0.43795134802144015
# Hausdorff mean: 1.7153551207623932 STD: 1.952382570630452
# --------------------------------
#
# patient idx:  11
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.5598958333333333 STD: 0.46758390837530733
# Hausdorff mean: 1.658229318073957 STD: 1.862895113651428
# --------------------------------
#
# patient idx:  12
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.7402142532134937 STD: 0.328788349909643
# Hausdorff mean: 0.8747197463668457 STD: 1.0569115237147821
# --------------------------------
#
# patient idx:  13
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.5859375 STD: 0.4502046096367678
# Hausdorff mean: 1.652208458822346 STD: 1.9112852680509322
# --------------------------------
#
# patient idx:  14
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.6614583333333333 STD: 0.4506638140164894
# Hausdorff mean: 1.067869175867614 STD: 1.532137962971744
# --------------------------------
#
# patient idx:  15
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.5677083333333334 STD: 0.4416654382844553
# Hausdorff mean: 1.4203223992424965 STD: 1.5363059756437198
# --------------------------------
#
# patient idx:  16
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.7552083333333333 STD: 0.4092769178516072
# Hausdorff mean: 0.6199690459577261 STD: 1.077711500566602
# --------------------------------
#
# patient idx:  17
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.5572916666666667 STD: 0.4547385065892265
# Hausdorff mean: 1.6256963305258219 STD: 1.7694722100621751
# --------------------------------
#
# patient idx:  18
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.6828798215338341 STD: 0.3689764095246789
# Hausdorff mean: 1.0747163192503175 STD: 1.273734208289194
# --------------------------------
#
# patient idx:  19
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.7552083333333334 STD: 0.387487398988664
# Hausdorff mean: 0.6542881158416127 STD: 1.0529257742099545
# --------------------------------
#
# patient idx:  20
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.6360777700726511 STD: 0.4013183165364966
# Hausdorff mean: 1.3165866760101512 STD: 1.5546492998508532
# --------------------------------
#
# patient idx:  21
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.8020833333333334 STD: 0.2839377743841461
# Hausdorff mean: 0.6777112133086727 STD: 0.9861088824860417
# --------------------------------
#
# patient idx:  22
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.6223958333333334 STD: 0.4256757164065087
# Hausdorff mean: 1.4191341347260817 STD: 1.620850361787266
# --------------------------------
#
# patient idx:  23
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.6796875 STD: 0.43780216499816826
# Hausdorff mean: 1.0716263733848643 STD: 1.5139668279082787
# --------------------------------
#
# patient idx:  24
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.7083333333333333 STD: 0.43898557303553093
# Hausdorff mean: 0.8430224244052797 STD: 1.3330019613824504
# --------------------------------
#
# patient idx:  25
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.5833333333333334 STD: 0.45643546458763845
# Hausdorff mean: 1.3317401413187868 STD: 1.5250581785354453
# --------------------------------
#
# patient idx:  26
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.7292880959985077 STD: 0.4159333581117805
# Hausdorff mean: 0.8664737584446072 STD: 1.3713658058714937
# --------------------------------
#
# patient idx:  27
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.5442708333333334 STD: 0.4892438428436444
# Hausdorff mean: 1.6747829110150092 STD: 1.8689571729089076
# --------------------------------
#
# patient idx:  28
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.7238525448888999 STD: 0.3965522056768488
# Hausdorff mean: 0.8891623259506558 STD: 1.2823372293044435
# --------------------------------
#
# patient idx:  29
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.7772934740872559 STD: 0.3196582120756236
# Hausdorff mean: 0.7686301734503753 STD: 1.0956495920861997
# --------------------------------
#
# patient idx:  30
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.7291666666666667 STD: 0.3673998351780916
# Hausdorff mean: 1.101457566980827 STD: 1.502365896149161
# --------------------------------
#
# patient idx:  31
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.7066925521691841 STD: 0.3800157849982643
# Hausdorff mean: 1.128015940520809 STD: 1.4933323729144259
# --------------------------------
#
# patient idx:  32
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.7369791666666667 STD: 0.41802350692724216
# Hausdorff mean: 0.795630282703258 STD: 1.2659037383014622
# --------------------------------
#
# patient idx:  33
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.625031001984127 STD: 0.4601814045982523
# Hausdorff mean: 1.2311387714128972 STD: 1.5846700250457209
# --------------------------------
#
# patient idx:  34
# dice shape:  (128,)
# hausdorff shape:  (128,)
# Dice mean: 0.8151041666666667 STD: 0.3084701097249942
# Hausdorff mean: 0.49602439635231527 STD: 0.8329631155926619
# --------------------------------

# %%
rows = 5
cols = 5
fig,ax = plt.subplots(rows,cols,figsize=[24,24])
num = 5
print('Patient: {}'.format(num))
print('Segmentation resullts: \n')
for i in range(rows*cols):
    #ind = start_with + i*show_every
    #ax[int(i/rows),int(i % rows)].set_title('slice %d' % ind)
    ax[int(i/rows),int(i % rows)].imshow(test_output[num][i+35],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
    #ax[int(i/rows),int(i % rows)].axis('off')
    ax[int(i/rows),int(i % rows)].set_xlabel('CT idx: {}'.format(i+35))
plt.show()
# Out:
# Patient: 5
# Segmentation resullts:

# %%
### flair CT model result
num=2
slice_num=65
fig = plt.figure(figsize=(20, 20))
fig.add_subplot(1,3,1)
plt.imshow(data_3d[num][slice_num],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
plt.xlabel('original CT')
fig.add_subplot(1,3,2)
plt.imshow(resize_nii_label[num][slice_num],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
plt.xlabel('Ground truth CT')
fig.add_subplot(1,3,3)
plt.imshow(test_output[num][slice_num],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
plt.xlabel('Ouput segmentation CT')
plt.show()

# %%
# flair + t1ce CT model result

image_seg_h = data_3d.shape[2]//input_height
image_seg_w = data_3d.shape[3]//input_width

print(image_seg_h)
print(image_seg_w)
for i in range(test_output.shape[1]//(image_seg_h*image_seg_w)):
    for j in range(image_seg_h):
        for k in range(image_seg_w):
            if k == 0:
                ww = test_output[0][i*(image_seg_h*image_seg_w)+j*image_seg_w+k]
            else:
                ww = np.concatenate((ww,test_output[0][i*(image_seg_h*image_seg_w)+j*image_seg_w+k]),axis = 2)
        if j == 0:
            hh = ww
        else:
            hh = np.concatenate((hh,ww), axis = 1)
    if i == 0:
        test_resized = hh
    else:
        test_resized = np.concatenate((test_resized,hh), axis = 0)

print(test_resized.shape)

num=1
slice_num=65
fig = plt.figure(figsize=(20, 20))
fig.add_subplot(1,3,1)
plt.imshow(data_3d[num][slice_num],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
plt.xlabel('original CT')
fig.add_subplot(1,3,2)
plt.imshow(resize_nii_label[num][slice_num],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
plt.xlabel('Ground truth CT')
fig.add_subplot(1,3,3)
plt.imshow(test_output[num][slice_num],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
plt.xlabel('Ouput segmentation CT')
plt.show()
# Out:
# 1
# 1
# (16384, 128)

# %%
for i in range(test_output.shape[0]):
    print(np.unique(test_output[i]))
    #for j in range(128):
    ##    for k in range(128):
     #       for l in range(128):
     ##           if test_output[i,j,k,l]!=0:
      #              test_output[i,j,k,l] = 1
    #print(np.unique(test_output[i]))
# Out:
# [0.]
# [0.  0.5]
# [0.  0.5]
# [0.]
# [0.]
# [0.  0.5]
# [0.]
# [0.  0.5]
# [0.  0.5]
# [0.  0.5]
# [0.  0.5]
# [0.]
# [0.  0.5]
# [0.]
# [0.]
# [0.  0.5]
# [0.  0.5]
# [0.]
# [0.  0.5]
# [0.]
# [0.  0.5]
# [0.]
# [0.]
# [0.]
# [0.]
# [0.  0.5]
# [0.  0.5]
# [0.]
# [0.  0.5]
# [0.  0.5]
# [0.]
# [0.  0.5]
# [0.]
# [0.  0.5]
# [0.]

# %%
np.where(test_output[4][60]!=0)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
test_data = np.load('./test_nii_data.npy')
test_label = np.load('./test_nii_label.npy')
trof = np.load('./testing_result_only_flair.npy')
trft = np.load('./testing_result_flair_t1ne.npy')

# %%
print(test_data.shape)
print(trof.shape)
print(trft.shape)
print(np.unique(trof[1]))
print(np.unique(trft[1]))
# Out:
# (35, 128, 128, 128)
# (35, 128, 128, 128)
# (35, 128, 128, 128)
# [0.  0.5]
# [0.  0.5 1. ]

# %%
t1 = 1
sl_num = 65
ROIrx = 35
ROIry = 40
ROIbx = 45
ROIby = 50
ROIgx = 330
ROIgy = 230
ROIs = 5

fig=plt.figure(figsize=(10,10))
fig.add_subplot(2,2,1)
rect = patches.Rectangle((30,35),25,25,linewidth=1,edgecolor='r',facecolor='none')
plt.gca().add_patch(rect)
plt.imshow(test_data[t1][sl_num],cmap = plt.cm.gray,vmin= 0,vmax = 1)
plt.xlabel('original MRI')
fig.add_subplot(2,2,2)
rect = patches.Rectangle((35,40),5,5,linewidth=1,edgecolor='r',facecolor='none')
plt.gca().add_patch(rect)
rect = patches.Rectangle((45,50),5,5,linewidth=1,edgecolor='b',facecolor='none')
plt.gca().add_patch(rect)
'''
rect = patches.Rectangle((ROIgx,ROIgy),ROIs,ROIs,linewidth=1,edgecolor='g',facecolor='none')
plt.gca().add_patch(rect)
'''
plt.imshow(resize_nii_label[t1][sl_num],cmap = plt.cm.gray,vmin= 0,vmax = 1)
plt.xlabel('Ground truth MRI')
fig.add_subplot(2,2,3)
plt.imshow(trof[t1][sl_num],cmap = plt.cm.gray,vmin= 0,vmax = 1)
plt.xlabel('only FLAIR testing result')
fig.add_subplot(2,2,4)
plt.imshow(trft[t1][sl_num],cmap = plt.cm.gray,vmin= 0,vmax = 1)
plt.xlabel('FLAIR and T1CE result')
rect = patches.Rectangle((35,45),5,5,linewidth=1,edgecolor='r',facecolor='none')
plt.gca().add_patch(rect)
rect = patches.Rectangle((45,45),5,5,linewidth=1,edgecolor='b',facecolor='none')
plt.gca().add_patch(rect)
plt.show()




print(np.max(nii_CT[t1]),np.min(nii_CT[t1]))
print(np.max(nii_label[t1]),np.min(nii_label[t1]))

print("red ROI",np.mean(nii_label[t1,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]),
      np.std(nii_label[t1,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]))
print("red ROI",np.mean(test_resized[t1,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]),
      np.std(test_resized[t1,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]))
print("blue ROI",np.mean(nii_label[t1,ROIby:ROIby+ROIs,ROIbx:ROIbx+ROIs]),
      np.std(nii_label[t1,ROIby:ROIby+ROIs,ROIbx:ROIbx+ROIs]))
print("blue ROI",np.mean(test_resized[t1,ROIby:ROIby+ROIs,ROIbx:ROIbx+ROIs]),
      np.std(test_resized[t1,ROIby:ROIby+ROIs,ROIbx:ROIbx+ROIs]))
print("green ROI",np.mean(nii_label[t1,ROIgy:ROIgy+ROIs,ROIgx:ROIgx+ROIs]),
      np.std(nii_label[t1,ROIgy:ROIgy+ROIs,ROIgx:ROIgx+ROIs]))
print("green ROI",np.mean(test_resized[t1,ROIgy:ROIgy+ROIs,ROIgx:ROIgx+ROIs]),
      np.std(test_resized[t1,ROIgy:ROIgy+ROIs,ROIgx:ROIgx+ROIs]))
# Out:
# 1240 0
# 1.0 0.0
# red ROI 0.0 0.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-144-fa44d9846e6a> in <module>
#      46 print("red ROI",np.mean(nii_label[t1,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]),
#      47       np.std(nii_label[t1,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]))
# ---> 48 print("red ROI",np.mean(test_resized[t1,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]),
#      49       np.std(test_resized[t1,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]))
#      50 print("blue ROI",np.mean(nii_label[t1,ROIby:ROIby+ROIs,ROIbx:ROIbx+ROIs]),
#
# IndexError: too many indices for array

# %%
rows = 5
cols = 5
fig,ax = plt.subplots(rows,cols,figsize=[24,24])
num = 1
print('Patient: {}'.format(num))
print('Segmentation resullts: \n')
for i in range(rows*cols):
    #ind = start_with + i*show_every
    #ax[int(i/rows),int(i % rows)].set_title('slice %d' % ind)
    ax[int(i/rows),int(i % rows)].imshow(trft[num][i+60],cmap=pylab.cm.gray,vmin = 0,vmax = 1)
    #ax[int(i/rows),int(i % rows)].axis('off')
    ax[int(i/rows),int(i % rows)].set_xlabel('MRI slice idx: {}'.format(i+60))
plt.show()
# Out:
# Patient: 1
# Segmentation resullts:

# %%
t2 = 200
ROIrx = 180
ROIry = 200
ROIbx = 270
ROIby = 120
ROIgx = 190
ROIgy = 300
ROIts = 15

fig=plt.figure(figsize=(20,10))
fig.add_subplot(1,3,1)
plt.imshow(norm_nii_CT[t2],cmap = plt.cm.gray,vmin= 0,vmax = 1)
fig.add_subplot(1,3,2)
rect = patches.Rectangle((ROIrx,ROIry),ROIs,ROIs,linewidth=1,edgecolor='r',facecolor='none')
plt.gca().add_patch(rect)
rect = patches.Rectangle((ROIbx,ROIby),ROIs,ROIs,linewidth=1,edgecolor='b',facecolor='none')
plt.gca().add_patch(rect)
rect = patches.Rectangle((ROIgx,ROIgy),ROIs,ROIs,linewidth=1,edgecolor='g',facecolor='none')
plt.gca().add_patch(rect)
plt.imshow(nii_label[t2]/850,cmap = plt.cm.gray,vmin= 0,vmax = 1)
fig.add_subplot(1,3,3)
plt.imshow(test_resized[t2]/850,cmap = plt.cm.gray,vmin= 0,vmax = 1)
plt.show()




print(np.max(nii_CT[t2]),np.min(nii_CT[t2]))
print(np.max(nii_label[t2]),np.min(nii_label[t2]))

print("red ROI",np.mean(nii_label[t2,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]),
      np.std(nii_label[t2,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]))
print("red ROI",np.mean(test_resized[t2,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]),
      np.std(test_resized[t2,ROIry:ROIry+ROIs,ROIrx:ROIrx+ROIs]))
print("blue ROI",np.mean(nii_label[t2,ROIby:ROIby+ROIs,ROIbx:ROIbx+ROIs]),
      np.std(nii_label[t2,ROIby:ROIby+ROIs,ROIbx:ROIbx+ROIs]))
print("blue ROI",np.mean(test_resized[t2,ROIby:ROIby+ROIs,ROIbx:ROIbx+ROIs]),
      np.std(test_resized[t2,ROIby:ROIby+ROIs,ROIbx:ROIbx+ROIs]))
print("green ROI",np.mean(nii_label[t2,ROIgy:ROIgy+ROIts,ROIgx:ROIgx+ROIts]),
      np.std(nii_label[t2,ROIgy:ROIgy+ROIts,ROIgx:ROIgx+ROIts]))
print("green ROI",np.mean(test_resized[t2,ROIgy:ROIgy+ROIts,ROIgx:ROIgx+ROIts]),
      np.std(test_resized[t2,ROIgy:ROIgy+ROIts,ROIgx:ROIgx+ROIts]))
# Out:
# 1508.0 -1024.0
# 820 0
# red ROI 820.0 0.0
# red ROI 0.0 0.0
# blue ROI 600.0 0.0
# blue ROI 0.0 0.0
# green ROI 420.0 0.0
# green ROI 0.0 0.0
